# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !pip install tensorflow-federated
# Out:
# Requirement already satisfied: tensorflow-federated in /usr/local/lib/python3.7/dist-packages (0.19.0)
# Requirement already satisfied: numpy~=1.19.2 in /usr/local/lib/python3.7/dist-packages (from tensorflow-federated) (1.19.5)
# Requirement already satisfied: portpicker~=1.3.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow-federated) (1.3.9)
# Requirement already satisfied: tqdm~=4.28.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow-federated) (4.28.1)
# Requirement already satisfied: tensorflow~=2.5.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow-federated) (2.5.0)
# Requirement already satisfied: dm-tree~=0.1.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow-federated) (0.1.6)
# Requirement already satisfied: cachetools~=3.1.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow-federated) (3.1.1)
# Requirement already satisfied: retrying~=1.3.3 in /usr/local/lib/python3.7/dist-packages (from tensorflow-federated) (1.3.3)
# Requirement already satisfied: grpcio~=1.34.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow-federated) (1.34.1)
# Requirement already satisfied: tensorflow-model-optimization~=0.5.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow-federated) (0.5.0)
# Requirement already satisfied: jaxlib~=0.1.55 in /usr/local/lib/python3.7/dist-packages (from tensorflow-federated) (0.1.69+cuda110)
# Requirement already satisfied: absl-py~=0.10 in /usr/local/lib/python3.7/dist-packages (from tensorflow-federated) (0.12.0)
# Requirement already satisfied: semantic-version~=2.8.5 in /usr/local/lib/python3.7/dist-packages (from tensorflow-federated) (2.8.5)
# Requirement already satisfied: jax~=0.2.8 in /usr/local/lib/python3.7/dist-packages (from tensorflow-federated) (0.2.17)
# Requirement already satisfied: attrs~=19.3.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow-federated) (19.3.0)
# Requirement already satisfied: tensorflow-privacy~=0.5.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow-federated) (0.5.2)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from absl-py~=0.10->tensorflow-federated) (1.15.0)
# Requirement already satisfied: opt-einsum in /usr/local/lib/python3.7/dist-packages (from jax~=0.2.8->tensorflow-federated) (3.3.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/dist-packages (from jaxlib~=0.1.55->tensorflow-federated) (1.4.1)
# Requirement already satisfied: flatbuffers<3.0,>=1.12 in /usr/local/lib/python3.7/dist-packages (from jaxlib~=0.1.55->tensorflow-federated) (1.12)
# Requirement already satisfied: wrapt~=1.12.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow~=2.5.0->tensorflow-federated) (1.12.1)
# Requirement already satisfied: h5py~=3.1.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow~=2.5.0->tensorflow-federated) (3.1.0)
# Requirement already satisfied: typing-extensions~=3.7.4 in /usr/local/lib/python3.7/dist-packages (from tensorflow~=2.5.0->tensorflow-federated) (3.7.4.3)
# Requirement already satisfied: keras-preprocessing~=1.1.2 in /usr/local/lib/python3.7/dist-packages (from tensorflow~=2.5.0->tensorflow-federated) (1.1.2)
# Requirement already satisfied: gast==0.4.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow~=2.5.0->tensorflow-federated) (0.4.0)
# Requirement already satisfied: keras-nightly~=2.5.0.dev in /usr/local/lib/python3.7/dist-packages (from tensorflow~=2.5.0->tensorflow-federated) (2.5.0.dev2021032900)
# Requirement already satisfied: termcolor~=1.1.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow~=2.5.0->tensorflow-federated) (1.1.0)
# Requirement already satisfied: tensorflow-estimator<2.6.0,>=2.5.0rc0 in /usr/local/lib/python3.7/dist-packages (from tensorflow~=2.5.0->tensorflow-federated) (2.5.0)
# Requirement already satisfied: protobuf>=3.9.2 in /usr/local/lib/python3.7/dist-packages (from tensorflow~=2.5.0->tensorflow-federated) (3.17.3)
# Requirement already satisfied: astunparse~=1.6.3 in /usr/local/lib/python3.7/dist-packages (from tensorflow~=2.5.0->tensorflow-federated) (1.6.3)
# Requirement already satisfied: tensorboard~=2.5 in /usr/local/lib/python3.7/dist-packages (from tensorflow~=2.5.0->tensorflow-federated) (2.5.0)
# Requirement already satisfied: google-pasta~=0.2 in /usr/local/lib/python3.7/dist-packages (from tensorflow~=2.5.0->tensorflow-federated) (0.2.0)
# Requirement already satisfied: wheel~=0.35 in /usr/local/lib/python3.7/dist-packages (from tensorflow~=2.5.0->tensorflow-federated) (0.37.0)
# Requirement already satisfied: cached-property in /usr/local/lib/python3.7/dist-packages (from h5py~=3.1.0->tensorflow~=2.5.0->tensorflow-federated) (1.5.2)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.5->tensorflow~=2.5.0->tensorflow-federated) (0.6.1)
# Requirement already satisfied: google-auth<2,>=1.6.3 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.5->tensorflow~=2.5.0->tensorflow-federated) (1.34.0)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.5->tensorflow~=2.5.0->tensorflow-federated) (1.8.0)
# Requirement already satisfied: werkzeug>=0.11.15 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.5->tensorflow~=2.5.0->tensorflow-federated) (1.0.1)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.5->tensorflow~=2.5.0->tensorflow-federated) (2.23.0)
# Requirement already satisfied: setuptools>=41.0.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.5->tensorflow~=2.5.0->tensorflow-federated) (57.2.0)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.5->tensorflow~=2.5.0->tensorflow-federated) (0.4.5)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.5->tensorflow~=2.5.0->tensorflow-federated) (3.3.4)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.7/dist-packages (from google-auth<2,>=1.6.3->tensorboard~=2.5->tensorflow~=2.5.0->tensorflow-federated) (4.7.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.7/dist-packages (from google-auth<2,>=1.6.3->tensorboard~=2.5->tensorflow~=2.5.0->tensorflow-federated) (0.2.8)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.7/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard~=2.5->tensorflow~=2.5.0->tensorflow-federated) (1.3.0)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from markdown>=2.6.8->tensorboard~=2.5->tensorflow~=2.5.0->tensorflow-federated) (4.6.3)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.7/dist-packages (from pyasn1-modules>=0.2.1->google-auth<2,>=1.6.3->tensorboard~=2.5->tensorflow~=2.5.0->tensorflow-federated) (0.4.8)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard~=2.5->tensorflow~=2.5.0->tensorflow-federated) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard~=2.5->tensorflow~=2.5.0->tensorflow-federated) (2021.5.30)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard~=2.5->tensorflow~=2.5.0->tensorflow-federated) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard~=2.5->tensorflow~=2.5.0->tensorflow-federated) (3.0.4)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.7/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard~=2.5->tensorflow~=2.5.0->tensorflow-federated) (3.1.1)
# Requirement already satisfied: mpmath in /usr/local/lib/python3.7/dist-packages (from tensorflow-privacy~=0.5.0->tensorflow-federated) (1.2.1)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->markdown>=2.6.8->tensorboard~=2.5->tensorflow~=2.5.0->tensorflow-federated) (3.5.0)

# %%
import os
import collections
import numpy as np
import scipy.io as sio
import tensorflow as tf
import tensorflow_federated as tff
import matplotlib.pyplot as plt
from keras import backend as K 
from keras.layers import Layer
import tensorflow_probability as tfp
tfd = tfp.distributions

################################ Functions ################################

def dc_compensation(z):
    """
    Function to estimate and remove DC impairments in the IQ branch
    Parameters:
    z: DC impaired signal sequence (numpy format)
    Returns:
    v: DC removed signal sequence
    """
    iDCest=np.mean(z[:, 0]) # estimated DC on I branch
    qDCest=np.mean(z[:, 1]) # estimated DC on I branch
    v=z-(iDCest+1j*qDCest) # remove estimated DCs
    return v

def blind_iq_compensation(z):
    """
    Function to estimate and compensate IQ impairments for the
    single-branch IQ impairment model
    Parameters:
    z: DC impaired signal sequence (numpy format)
    Returns:
    y: IQ imbalance compensated signal sequence
    """
    I=z[:, 0];Q=z[:, 1]
    theta1=(-1)*np.mean(np.sign(I)*Q)
    theta2=np.mean(abs(I)); theta3=np.mean(abs(Q))
    c1=theta1/theta2
    c2=np.sqrt((theta3**2-theta1**2)/theta2**2)
    x_u2 = I +1j*(c1*I+Q)/c2
    return x_u2


def usergen(x, y, iid, N0):
    if iid==True:
        sigma = 1 # i.i.d. user fading 
    else:
        sigma = np.random.uniform(low=0.5, high=1.5, size=None) #non-i.i.d. user fading
        
    h = np.random.rayleigh(scale=sigma, size=(x.shape[0],1))
    hIQ=np.concatenate((h,h),axis=1)
    x_u = np.multiply(hIQ,x)+ np.random.normal(0, np.sqrt(N0)/2, x.shape) # Channel-distorted noisy features
    y_u = np.real(y) # Labels
    # print(y_u)
    # y_u = np.interp(y_u, (y_u.min(), y_u.max()), (0, 1))
    D_u = tf.data.Dataset.from_tensor_slices((list(x_u),list(y_u.astype(int))))

    return D_u


def testgen(x, y, iid, N0):
    if iid==True:
        h = np.random.rayleigh(scale=1, size=(x.shape[0],1)) # i.i.d. test fading 
    else:
        h = np.random.rayleigh(scale=np.random.uniform(low=0.5, high=1.5, size=(x.shape[0],1)), size=(x.shape[0],1)) # non-i.i.d. user fading
    hIQ = np.concatenate((h,h),axis=1)
    x_test = np.multiply(hIQ,x) + np.random.normal(0, np.sqrt(N0)/2, x.shape) # Channel-distorted noisy features
    y_test = np.real(y) # Labels
    # print(y_test)
    # y_test = np.interp(y_test, (y_test.min(), y_test.max()), (0, 1))

    dataset_test = tf.data.Dataset.from_tensor_slices((list(x_test),list(y_test.astype(int))))
    
    return dataset_test


def preprocess(dataset):
    EPOCH = 5 # Number of local epochs for each aggragation round
    AGGREGATION_ROUND = 5 # Number of federated aggregation rounds
    BATCH_SIZE = 1000
    SHUFFLE_BUFFER = 20
    PREFETCH_BUFFER = 10
    def batch_format_fn(element1,element2):
        return collections.OrderedDict(
            x=tf.reshape(element1, [-1, 2]),
            y=tf.reshape(element2, [-1, 1]))
    return dataset.repeat(EPOCH).shuffle(SHUFFLE_BUFFER).batch(
        BATCH_SIZE).map(batch_format_fn).prefetch(PREFETCH_BUFFER)

# %%
class CompensateLayer(Layer): 
   def __init__(self, output_dim, **kwargs): 
      self.output_dim = output_dim 
      super(CompensateLayer, self).__init__(**kwargs) 
   def build(self, input_shape): 
    self.kernel = self.add_weight(name = 'kernel', 
      shape = (input_shape[1], self.output_dim), 
      initializer = 'normal', trainable = True) 
    super(CompensateLayer, self).build(input_shape)   
   def call(self, input_data): 
     x = K.dot(input_data, self.kernel)
     return x - K.mean(x, axis = [0, 1])
   def compute_output_shape(self, input_shape): return (input_shape[0], self.output_dim)

# %%
def create_keras_model():
    Q = 4 
    M = 2**Q # 16QAM modulation
    Es = 10 # Average symbol energy
    model = tf.keras.models.Sequential()
    model.add(tf.keras.layers.Input(shape=(2,)))
    model.add(CompensateLayer(2, input_shape = (2, )))
    model.add(tf.keras.layers.Dense(M, activation=tf.keras.activations.softmax))
    return model

# %%
def model_fn():
  keras_model = create_keras_model()
  return tff.learning.from_keras_model(
      keras_model,
      input_spec=preprocessed_example_dataset.element_spec,
      loss=tf.keras.losses.SparseCategoricalCrossentropy(),
      metrics=[tf.keras.metrics.SparseCategoricalAccuracy()])

# %%
# %cd "/content/drive/MyDrive/Tasnim_BUET/11 august/fedrec_moderation"
def train(user_g, snr_g, iid_g):
    os.environ["CUDA_VISIBLE_DEVICES"] = "0"

    MC = 10 # Number of Monte Carlo trials
    iid = iid_g # set to False to simulate non-iid user fading 

    ### Modulation Parameters
    Q = 4 
    M = 2**Q # 16QAM modulation
    Es = 10 # Average symbol energy

    ### Noise Parameters
    EbN0_dB = snr_g # SNR per bit (dB)
    EsN0_dB = EbN0_dB + 10*np.log10(Q) # SNR per symbol (dB)
    N0 = Es/10**(EsN0_dB/10)

    ### FedRec Training Parameters
    U = user_g # Number of wireless users taking part in federated training
    EPOCH = 5 # Number of local epochs for each aggragation round
    AGGREGATION_ROUND = 5 # Number of federated aggregation rounds
    BATCH_SIZE = 1000 
    SHUFFLE_BUFFER = 20
    PREFETCH_BUFFER = 10

    ### Load QAM I/Q Symbols
    TRAIN = sio.loadmat('TRAIN_fedrec.mat')
    Train = TRAIN['TRAIN']
    TEST = sio.loadmat('TEST_fedrec.mat')
    Test = TEST['TEST']


    ### Generate Real-valued Train/Test Features/Labels
    N_T = int(Train.shape[0]/U) # Size of local user datasets 
    x_train = np.zeros((N_T,2))
    x_train[:,0] = np.real(Train[0:N_T,0])
    x_train[:,1] = np.imag(Train[0:N_T,0])
    y_train = Train[0:N_T,1]-1

    x_test = np.zeros((Test.shape[0],2))
    x_test[:,0] = np.real(Test[:,0])
    x_test[:,1] = np.imag(Test[:,0])
    y_test = Test[:,1]-1


    example_dataset = usergen(x_train, y_train, iid, N0)
    # print(f"uplink dataset: U_U: {len(example_dataset)}")
    preprocessed_example_dataset=preprocess(example_dataset)
    example_element = next(iter((preprocessed_example_dataset)))

    def model_fn():
        keras_model = create_keras_model()
        return tff.learning.from_keras_model(
            keras_model,
            input_spec=preprocessed_example_dataset.element_spec,
            loss=tf.keras.losses.SparseCategoricalCrossentropy(),
            metrics=[tf.keras.metrics.SparseCategoricalAccuracy()])


    iterative_process = tff.learning.build_federated_averaging_process(
        model_fn,
        client_optimizer_fn=lambda: tf.keras.optimizers.Adam(learning_rate=0.05),
        server_optimizer_fn=lambda: tf.keras.optimizers.SGD(learning_rate=1.0))

    evaluation = tff.learning.build_federated_evaluation(model_fn)
    print(evaluation)


    BER = 0
    for i in range(MC):
        
        print('##############################')
        print('Monte Carlo Trial # ', i+1)
        
        ### Generate Federated User Datasets
        federated_train_data=[]
        for u in range(U):
            D_u = usergen(x_train, y_train, iid, N0) ### Generate Local Dataset at user u
            # print(f"downlink dataset: D_U: {len(D_u)}")
            federated_train_data.append(preprocess(D_u))
            print(D_u)
                
        ### Generate Test Dataset
        test_dataset = testgen(x_test, y_test, iid, N0)
        federated_test_data=[preprocess(test_dataset)]
        print(federated_test_data)
        
        ### Federated Training
        state = iterative_process.initialize()
        for n in range(AGGREGATION_ROUND):
            state, metrics = iterative_process.next(state, federated_train_data)
            # print(str(metrics))
            
            ### Evaluate the Model
            test_metrics = evaluation(state.model, federated_test_data)
            print(str(test_metrics))
        
        BER = BER + (1-test_metrics['sparse_categorical_accuracy'])/(Q*MC)

        
    print('##############################')
    print('4QAM at Eb/N0=', EbN0_dB, 'dB')
    print('FedRec trained collaboratively by ', U, 'users')
    if iid==True:
            iidstr = 'iid' 
    else:
            iidstr = 'non-iid'
    print(iidstr, ' Rayleigh fading')
    print('BER= ', BER)

    return BER
# Out:
# /content/drive/MyDrive/Tasnim_BUET/11 august/fedrec_moderation

# %%
# !pip install nest_asyncio
import nest_asyncio
nest_asyncio.apply()
# Out:
# Requirement already satisfied: nest_asyncio in /usr/local/lib/python3.7/dist-packages (1.5.1)

# %%
def main():
    ber = []
    iid = False
    dataset_setup = 'compensate in model'
    # %cd "/content/drive/MyDrive/Tasnim_BUET/11 august/fedrec_moderation"
    for i in [1, 5, 10, 100, 1000]:
      print(i)
      x = train(i, 5, iid)
      ber.append(x)
      with open(f'user_change_{iid}_dataset_setup_{dataset_setup}_5db.txt', 'a+') as f:
        f.write(str(x) + '\n')
    with open(f'user_change_{iid}_dataset_setup_{dataset_setup}_5db.txt', 'a+') as f:
        f.write(str(ber) + '\n')
main()
# Out:
# /content/drive/MyDrive/Tasnim_BUET/11 august/fedrec_moderation
# 1
# WARNING:tensorflow:Please add `keras.layers.InputLayer` instead of `keras.Input` to Sequential model. `keras.Input` is intended to be used by Functional model.
# WARNING:tensorflow:Please add `keras.layers.InputLayer` instead of `keras.Input` to Sequential model. `keras.Input` is intended to be used by Functional model.
# WARNING:tensorflow:Please add `keras.layers.InputLayer` instead of `keras.Input` to Sequential model. `keras.Input` is intended to be used by Functional model.
# WARNING:tensorflow:Please add `keras.layers.InputLayer` instead of `keras.Input` to Sequential model. `keras.Input` is intended to be used by Functional model.
# WARNING:tensorflow:Please add `keras.layers.InputLayer` instead of `keras.Input` to Sequential model. `keras.Input` is intended to be used by Functional model.
# WARNING:tensorflow:Please add `keras.layers.InputLayer` instead of `keras.Input` to Sequential model. `keras.Input` is intended to be used by Functional model.
# WARNING:tensorflow:Please add `keras.layers.InputLayer` instead of `keras.Input` to Sequential model. `keras.Input` is intended to be used by Functional model.
# WARNING:tensorflow:Please add `keras.layers.InputLayer` instead of `keras.Input` to Sequential model. `keras.Input` is intended to be used by Functional model.
# WARNING:tensorflow:Please add `keras.layers.InputLayer` instead of `keras.Input` to Sequential model. `keras.Input` is intended to be used by Functional model.
# WARNING:tensorflow:Please add `keras.layers.InputLayer` instead of `keras.Input` to Sequential model. `keras.Input` is intended to be used by Functional model.
# WARNING:tensorflow:Please add `keras.layers.InputLayer` instead of `keras.Input` to Sequential model. `keras.Input` is intended to be used by Functional model.
# WARNING:tensorflow:Please add `keras.layers.InputLayer` instead of `keras.Input` to Sequential model. `keras.Input` is intended to be used by Functional model.
# <tensorflow_federated.python.core.impl.computation.computation_impl.ComputationImpl object at 0x7f61d2f617d0>
# ##############################
# Monte Carlo Trial #  1
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# [<PrefetchDataset shapes: OrderedDict([(x, (None, 2)), (y, (None, 1))]), types: OrderedDict([(x, tf.float64), (y, tf.int32)])>]
# OrderedDict([('sparse_categorical_accuracy', 0.728837), ('loss', 0.76562315)])
# OrderedDict([('sparse_categorical_accuracy', 0.72959), ('loss', 0.76247346)])
# OrderedDict([('sparse_categorical_accuracy', 0.7293668), ('loss', 0.7630901)])
# OrderedDict([('sparse_categorical_accuracy', 0.7295486), ('loss', 0.7627024)])
# OrderedDict([('sparse_categorical_accuracy', 0.729395), ('loss', 0.7632223)])
# ##############################
# Monte Carlo Trial #  2
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# [<PrefetchDataset shapes: OrderedDict([(x, (None, 2)), (y, (None, 1))]), types: OrderedDict([(x, tf.float64), (y, tf.int32)])>]
# OrderedDict([('sparse_categorical_accuracy', 0.7392366), ('loss', 0.7375034)])
# OrderedDict([('sparse_categorical_accuracy', 0.7393744), ('loss', 0.73732656)])
# OrderedDict([('sparse_categorical_accuracy', 0.739777), ('loss', 0.7366237)])
# OrderedDict([('sparse_categorical_accuracy', 0.7399438), ('loss', 0.7364453)])
# OrderedDict([('sparse_categorical_accuracy', 0.7399736), ('loss', 0.7362084)])
# ##############################
# Monte Carlo Trial #  3
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# [<PrefetchDataset shapes: OrderedDict([(x, (None, 2)), (y, (None, 1))]), types: OrderedDict([(x, tf.float64), (y, tf.int32)])>]
# OrderedDict([('sparse_categorical_accuracy', 0.7171782), ('loss', 0.7763303)])
# OrderedDict([('sparse_categorical_accuracy', 0.7179424), ('loss', 0.77672315)])
# OrderedDict([('sparse_categorical_accuracy', 0.722562), ('loss', 0.76941305)])
# OrderedDict([('sparse_categorical_accuracy', 0.7250302), ('loss', 0.7646586)])
# OrderedDict([('sparse_categorical_accuracy', 0.7221314), ('loss', 0.7703027)])
# ##############################
# Monte Carlo Trial #  4
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# [<PrefetchDataset shapes: OrderedDict([(x, (None, 2)), (y, (None, 1))]), types: OrderedDict([(x, tf.float64), (y, tf.int32)])>]
# OrderedDict([('sparse_categorical_accuracy', 0.7268936), ('loss', 0.77664995)])
# OrderedDict([('sparse_categorical_accuracy', 0.7276858), ('loss', 0.77321076)])
# OrderedDict([('sparse_categorical_accuracy', 0.727852), ('loss', 0.77301085)])
# OrderedDict([('sparse_categorical_accuracy', 0.727872), ('loss', 0.77267444)])
# OrderedDict([('sparse_categorical_accuracy', 0.7278324), ('loss', 0.7731114)])
# ##############################
# Monte Carlo Trial #  5
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# [<PrefetchDataset shapes: OrderedDict([(x, (None, 2)), (y, (None, 1))]), types: OrderedDict([(x, tf.float64), (y, tf.int32)])>]
# OrderedDict([('sparse_categorical_accuracy', 0.7257548), ('loss', 0.7810426)])
# OrderedDict([('sparse_categorical_accuracy', 0.7259438), ('loss', 0.7782473)])
# OrderedDict([('sparse_categorical_accuracy', 0.7255132), ('loss', 0.78003645)])
# OrderedDict([('sparse_categorical_accuracy', 0.7260414), ('loss', 0.7783083)])
# OrderedDict([('sparse_categorical_accuracy', 0.7258986), ('loss', 0.77854496)])
# ##############################
# Monte Carlo Trial #  6
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# [<PrefetchDataset shapes: OrderedDict([(x, (None, 2)), (y, (None, 1))]), types: OrderedDict([(x, tf.float64), (y, tf.int32)])>]
# OrderedDict([('sparse_categorical_accuracy', 0.7421628), ('loss', 0.7309241)])
# OrderedDict([('sparse_categorical_accuracy', 0.7424004), ('loss', 0.730466)])
# OrderedDict([('sparse_categorical_accuracy', 0.7421486), ('loss', 0.7313248)])
# OrderedDict([('sparse_categorical_accuracy', 0.7422328), ('loss', 0.7311279)])
# OrderedDict([('sparse_categorical_accuracy', 0.7421376), ('loss', 0.73135835)])
# ##############################
# Monte Carlo Trial #  7
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# [<PrefetchDataset shapes: OrderedDict([(x, (None, 2)), (y, (None, 1))]), types: OrderedDict([(x, tf.float64), (y, tf.int32)])>]
# OrderedDict([('sparse_categorical_accuracy', 0.7408752), ('loss', 0.7324452)])
# OrderedDict([('sparse_categorical_accuracy', 0.740968), ('loss', 0.732583)])
# OrderedDict([('sparse_categorical_accuracy', 0.7415216), ('loss', 0.7311114)])
# OrderedDict([('sparse_categorical_accuracy', 0.741294), ('loss', 0.73175895)])
# OrderedDict([('sparse_categorical_accuracy', 0.7412846), ('loss', 0.7317579)])
# ##############################
# Monte Carlo Trial #  8
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# [<PrefetchDataset shapes: OrderedDict([(x, (None, 2)), (y, (None, 1))]), types: OrderedDict([(x, tf.float64), (y, tf.int32)])>]
# OrderedDict([('sparse_categorical_accuracy', 0.74202), ('loss', 0.7284005)])
# OrderedDict([('sparse_categorical_accuracy', 0.7415382), ('loss', 0.7286351)])
# OrderedDict([('sparse_categorical_accuracy', 0.7418688), ('loss', 0.7279869)])
# OrderedDict([('sparse_categorical_accuracy', 0.742084), ('loss', 0.727546)])
# OrderedDict([('sparse_categorical_accuracy', 0.7420692), ('loss', 0.7276217)])
# ##############################
# Monte Carlo Trial #  9
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# [<PrefetchDataset shapes: OrderedDict([(x, (None, 2)), (y, (None, 1))]), types: OrderedDict([(x, tf.float64), (y, tf.int32)])>]
# OrderedDict([('sparse_categorical_accuracy', 0.742109), ('loss', 0.7299995)])
# OrderedDict([('sparse_categorical_accuracy', 0.7425794), ('loss', 0.7308335)])
# OrderedDict([('sparse_categorical_accuracy', 0.7425468), ('loss', 0.73103917)])
# OrderedDict([('sparse_categorical_accuracy', 0.7425792), ('loss', 0.7308912)])
# OrderedDict([('sparse_categorical_accuracy', 0.742679), ('loss', 0.7308072)])
# ##############################
# Monte Carlo Trial #  10
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# [<PrefetchDataset shapes: OrderedDict([(x, (None, 2)), (y, (None, 1))]), types: OrderedDict([(x, tf.float64), (y, tf.int32)])>]
# OrderedDict([('sparse_categorical_accuracy', 0.7206336), ('loss', 0.8007975)])
# OrderedDict([('sparse_categorical_accuracy', 0.7205834), ('loss', 0.8011693)])
# OrderedDict([('sparse_categorical_accuracy', 0.7205296), ('loss', 0.80157524)])
# OrderedDict([('sparse_categorical_accuracy', 0.720662), ('loss', 0.8012355)])
# OrderedDict([('sparse_categorical_accuracy', 0.7207216), ('loss', 0.8012118)])
# ##############################
# 4QAM at Eb/N0= 5 dB
# FedRec trained collaboratively by  1 users
# non-iid  Rayleigh fading
# BER=  0.06664692610502243
# 5
# WARNING:tensorflow:Please add `keras.layers.InputLayer` instead of `keras.Input` to Sequential model. `keras.Input` is intended to be used by Functional model.
# WARNING:tensorflow:Please add `keras.layers.InputLayer` instead of `keras.Input` to Sequential model. `keras.Input` is intended to be used by Functional model.
# WARNING:tensorflow:Please add `keras.layers.InputLayer` instead of `keras.Input` to Sequential model. `keras.Input` is intended to be used by Functional model.
# WARNING:tensorflow:Please add `keras.layers.InputLayer` instead of `keras.Input` to Sequential model. `keras.Input` is intended to be used by Functional model.
# WARNING:tensorflow:Please add `keras.layers.InputLayer` instead of `keras.Input` to Sequential model. `keras.Input` is intended to be used by Functional model.
# WARNING:tensorflow:Please add `keras.layers.InputLayer` instead of `keras.Input` to Sequential model. `keras.Input` is intended to be used by Functional model.
# WARNING:tensorflow:Please add `keras.layers.InputLayer` instead of `keras.Input` to Sequential model. `keras.Input` is intended to be used by Functional model.
# WARNING:tensorflow:Please add `keras.layers.InputLayer` instead of `keras.Input` to Sequential model. `keras.Input` is intended to be used by Functional model.
# WARNING:tensorflow:Please add `keras.layers.InputLayer` instead of `keras.Input` to Sequential model. `keras.Input` is intended to be used by Functional model.
# WARNING:tensorflow:Please add `keras.layers.InputLayer` instead of `keras.Input` to Sequential model. `keras.Input` is intended to be used by Functional model.
# WARNING:tensorflow:Please add `keras.layers.InputLayer` instead of `keras.Input` to Sequential model. `keras.Input` is intended to be used by Functional model.
# WARNING:tensorflow:Please add `keras.layers.InputLayer` instead of `keras.Input` to Sequential model. `keras.Input` is intended to be used by Functional model.
# <tensorflow_federated.python.core.impl.computation.computation_impl.ComputationImpl object at 0x7f61c2657190>
# ##############################
# Monte Carlo Trial #  1
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# [<PrefetchDataset shapes: OrderedDict([(x, (None, 2)), (y, (None, 1))]), types: OrderedDict([(x, tf.float64), (y, tf.int32)])>]
# OrderedDict([('sparse_categorical_accuracy', 0.4086566), ('loss', 1.6866162)])
# OrderedDict([('sparse_categorical_accuracy', 0.7302426), ('loss', 0.902265)])
# OrderedDict([('sparse_categorical_accuracy', 0.7386974), ('loss', 0.75825226)])
# OrderedDict([('sparse_categorical_accuracy', 0.7402772), ('loss', 0.73446286)])
# OrderedDict([('sparse_categorical_accuracy', 0.7402604), ('loss', 0.73284453)])
# ##############################
# Monte Carlo Trial #  2
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# [<PrefetchDataset shapes: OrderedDict([(x, (None, 2)), (y, (None, 1))]), types: OrderedDict([(x, tf.float64), (y, tf.int32)])>]
# OrderedDict([('sparse_categorical_accuracy', 0.5825998), ('loss', 1.3601596)])
# OrderedDict([('sparse_categorical_accuracy', 0.7382546), ('loss', 0.8479219)])
# OrderedDict([('sparse_categorical_accuracy', 0.7410636), ('loss', 0.7454357)])
# OrderedDict([('sparse_categorical_accuracy', 0.7422236), ('loss', 0.72921705)])
# OrderedDict([('sparse_categorical_accuracy', 0.741941), ('loss', 0.7295413)])
# ##############################
# Monte Carlo Trial #  3
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# [<PrefetchDataset shapes: OrderedDict([(x, (None, 2)), (y, (None, 1))]), types: OrderedDict([(x, tf.float64), (y, tf.int32)])>]
# OrderedDict([('sparse_categorical_accuracy', 0.324452), ('loss', 1.7999316)])
# OrderedDict([('sparse_categorical_accuracy', 0.734018), ('loss', 0.938858)])
# OrderedDict([('sparse_categorical_accuracy', 0.7372918), ('loss', 0.7762941)])
# OrderedDict([('sparse_categorical_accuracy', 0.7387722), ('loss', 0.741177)])
# OrderedDict([('sparse_categorical_accuracy', 0.7384014), ('loss', 0.7386241)])
# ##############################
# Monte Carlo Trial #  4
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# [<PrefetchDataset shapes: OrderedDict([(x, (None, 2)), (y, (None, 1))]), types: OrderedDict([(x, tf.float64), (y, tf.int32)])>]
# OrderedDict([('sparse_categorical_accuracy', 0.2611552), ('loss', 1.810341)])
# OrderedDict([('sparse_categorical_accuracy', 0.7110936), ('loss', 0.9425423)])
# OrderedDict([('sparse_categorical_accuracy', 0.7288272), ('loss', 0.78391075)])
# OrderedDict([('sparse_categorical_accuracy', 0.730496), ('loss', 0.76093966)])
# OrderedDict([('sparse_categorical_accuracy', 0.729407), ('loss', 0.7650598)])
# ##############################
# Monte Carlo Trial #  5
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# [<PrefetchDataset shapes: OrderedDict([(x, (None, 2)), (y, (None, 1))]), types: OrderedDict([(x, tf.float64), (y, tf.int32)])>]
# OrderedDict([('sparse_categorical_accuracy', 0.3571958), ('loss', 1.6252884)])
# OrderedDict([('sparse_categorical_accuracy', 0.7128516), ('loss', 0.9025317)])
# OrderedDict([('sparse_categorical_accuracy', 0.723841), ('loss', 0.7909141)])
# OrderedDict([('sparse_categorical_accuracy', 0.7237684), ('loss', 0.78499)])
# OrderedDict([('sparse_categorical_accuracy', 0.7231212), ('loss', 0.7899914)])
# ##############################
# Monte Carlo Trial #  6
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# [<PrefetchDataset shapes: OrderedDict([(x, (None, 2)), (y, (None, 1))]), types: OrderedDict([(x, tf.float64), (y, tf.int32)])>]
# OrderedDict([('sparse_categorical_accuracy', 0.6128584), ('loss', 1.4087068)])
# OrderedDict([('sparse_categorical_accuracy', 0.7371282), ('loss', 0.8551742)])
# OrderedDict([('sparse_categorical_accuracy', 0.740974), ('loss', 0.7467803)])
# OrderedDict([('sparse_categorical_accuracy', 0.7413558), ('loss', 0.7315938)])
# OrderedDict([('sparse_categorical_accuracy', 0.740811), ('loss', 0.73065895)])
# ##############################
# Monte Carlo Trial #  7
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# [<PrefetchDataset shapes: OrderedDict([(x, (None, 2)), (y, (None, 1))]), types: OrderedDict([(x, tf.float64), (y, tf.int32)])>]
# OrderedDict([('sparse_categorical_accuracy', 0.545368), ('loss', 1.3512865)])
# OrderedDict([('sparse_categorical_accuracy', 0.7318424), ('loss', 0.8242456)])
# OrderedDict([('sparse_categorical_accuracy', 0.7352426), ('loss', 0.7521019)])
# OrderedDict([('sparse_categorical_accuracy', 0.7337218), ('loss', 0.75077075)])
# OrderedDict([('sparse_categorical_accuracy', 0.7338632), ('loss', 0.7512401)])
# ##############################
# Monte Carlo Trial #  8
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# [<PrefetchDataset shapes: OrderedDict([(x, (None, 2)), (y, (None, 1))]), types: OrderedDict([(x, tf.float64), (y, tf.int32)])>]
# OrderedDict([('sparse_categorical_accuracy', 0.4480512), ('loss', 1.5374713)])
# OrderedDict([('sparse_categorical_accuracy', 0.7151576), ('loss', 0.9064762)])
# OrderedDict([('sparse_categorical_accuracy', 0.7282948), ('loss', 0.78488374)])
# OrderedDict([('sparse_categorical_accuracy', 0.7286174), ('loss', 0.77113944)])
# OrderedDict([('sparse_categorical_accuracy', 0.72909), ('loss', 0.7706051)])
# ##############################
# Monte Carlo Trial #  9
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# [<PrefetchDataset shapes: OrderedDict([(x, (None, 2)), (y, (None, 1))]), types: OrderedDict([(x, tf.float64), (y, tf.int32)])>]
# OrderedDict([('sparse_categorical_accuracy', 0.491262), ('loss', 1.4940774)])
# OrderedDict([('sparse_categorical_accuracy', 0.7297724), ('loss', 0.8919562)])
# OrderedDict([('sparse_categorical_accuracy', 0.7361916), ('loss', 0.7617047)])
# OrderedDict([('sparse_categorical_accuracy', 0.7370772), ('loss', 0.74076784)])
# OrderedDict([('sparse_categorical_accuracy', 0.7370512), ('loss', 0.7404086)])
# ##############################
# Monte Carlo Trial #  10
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# [<PrefetchDataset shapes: OrderedDict([(x, (None, 2)), (y, (None, 1))]), types: OrderedDict([(x, tf.float64), (y, tf.int32)])>]
# OrderedDict([('sparse_categorical_accuracy', 0.4382944), ('loss', 1.6967944)])
# OrderedDict([('sparse_categorical_accuracy', 0.726293), ('loss', 0.9227062)])
# OrderedDict([('sparse_categorical_accuracy', 0.7380918), ('loss', 0.7621064)])
# OrderedDict([('sparse_categorical_accuracy', 0.7409638), ('loss', 0.73272705)])
# OrderedDict([('sparse_categorical_accuracy', 0.7415934), ('loss', 0.72887266)])
# ##############################
# 4QAM at Eb/N0= 5 dB
# FedRec trained collaboratively by  5 users
# non-iid  Rayleigh fading
# BER=  0.0661115050315857
# 10
# WARNING:tensorflow:Please add `keras.layers.InputLayer` instead of `keras.Input` to Sequential model. `keras.Input` is intended to be used by Functional model.
# WARNING:tensorflow:Please add `keras.layers.InputLayer` instead of `keras.Input` to Sequential model. `keras.Input` is intended to be used by Functional model.
# WARNING:tensorflow:Please add `keras.layers.InputLayer` instead of `keras.Input` to Sequential model. `keras.Input` is intended to be used by Functional model.
# WARNING:tensorflow:Please add `keras.layers.InputLayer` instead of `keras.Input` to Sequential model. `keras.Input` is intended to be used by Functional model.
# WARNING:tensorflow:Please add `keras.layers.InputLayer` instead of `keras.Input` to Sequential model. `keras.Input` is intended to be used by Functional model.
# WARNING:tensorflow:Please add `keras.layers.InputLayer` instead of `keras.Input` to Sequential model. `keras.Input` is intended to be used by Functional model.
# WARNING:tensorflow:Please add `keras.layers.InputLayer` instead of `keras.Input` to Sequential model. `keras.Input` is intended to be used by Functional model.
# WARNING:tensorflow:Please add `keras.layers.InputLayer` instead of `keras.Input` to Sequential model. `keras.Input` is intended to be used by Functional model.
# WARNING:tensorflow:Please add `keras.layers.InputLayer` instead of `keras.Input` to Sequential model. `keras.Input` is intended to be used by Functional model.
# WARNING:tensorflow:Please add `keras.layers.InputLayer` instead of `keras.Input` to Sequential model. `keras.Input` is intended to be used by Functional model.
# WARNING:tensorflow:Please add `keras.layers.InputLayer` instead of `keras.Input` to Sequential model. `keras.Input` is intended to be used by Functional model.
# WARNING:tensorflow:Please add `keras.layers.InputLayer` instead of `keras.Input` to Sequential model. `keras.Input` is intended to be used by Functional model.
# <tensorflow_federated.python.core.impl.computation.computation_impl.ComputationImpl object at 0x7f61c26e62d0>
# ##############################
# Monte Carlo Trial #  1
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# [<PrefetchDataset shapes: OrderedDict([(x, (None, 2)), (y, (None, 1))]), types: OrderedDict([(x, tf.float64), (y, tf.int32)])>]
# OrderedDict([('sparse_categorical_accuracy', 0.387181), ('loss', 2.0891616)])
# OrderedDict([('sparse_categorical_accuracy', 0.6470526), ('loss', 1.3407441)])
# OrderedDict([('sparse_categorical_accuracy', 0.7313728), ('loss', 0.9698664)])
# OrderedDict([('sparse_categorical_accuracy', 0.7362682), ('loss', 0.83040285)])
# OrderedDict([('sparse_categorical_accuracy', 0.7409436), ('loss', 0.7686562)])
# ##############################
# Monte Carlo Trial #  2
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# [<PrefetchDataset shapes: OrderedDict([(x, (None, 2)), (y, (None, 1))]), types: OrderedDict([(x, tf.float64), (y, tf.int32)])>]
# OrderedDict([('sparse_categorical_accuracy', 0.344119), ('loss', 2.1350195)])
# OrderedDict([('sparse_categorical_accuracy', 0.609844), ('loss', 1.4253507)])
# OrderedDict([('sparse_categorical_accuracy', 0.715435), ('loss', 1.0316771)])
# OrderedDict([('sparse_categorical_accuracy', 0.7344454), ('loss', 0.8607278)])
# OrderedDict([('sparse_categorical_accuracy', 0.7399588), ('loss', 0.7845029)])
# ##############################
# Monte Carlo Trial #  3
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# [<PrefetchDataset shapes: OrderedDict([(x, (None, 2)), (y, (None, 1))]), types: OrderedDict([(x, tf.float64), (y, tf.int32)])>]
# OrderedDict([('sparse_categorical_accuracy', 0.3068394), ('loss', 2.240158)])
# OrderedDict([('sparse_categorical_accuracy', 0.5815612), ('loss', 1.4768457)])
# OrderedDict([('sparse_categorical_accuracy', 0.7078942), ('loss', 1.047733)])
# OrderedDict([('sparse_categorical_accuracy', 0.7340808), ('loss', 0.8647662)])
# OrderedDict([('sparse_categorical_accuracy', 0.7397782), ('loss', 0.7863699)])
# ##############################
# Monte Carlo Trial #  4
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# [<PrefetchDataset shapes: OrderedDict([(x, (None, 2)), (y, (None, 1))]), types: OrderedDict([(x, tf.float64), (y, tf.int32)])>]
# OrderedDict([('sparse_categorical_accuracy', 0.2864196), ('loss', 2.260114)])
# OrderedDict([('sparse_categorical_accuracy', 0.6205634), ('loss', 1.4871756)])
# OrderedDict([('sparse_categorical_accuracy', 0.6962462), ('loss', 1.0395825)])
# OrderedDict([('sparse_categorical_accuracy', 0.7310962), ('loss', 0.8542902)])
# OrderedDict([('sparse_categorical_accuracy', 0.739136), ('loss', 0.7802219)])
# ##############################
# Monte Carlo Trial #  5
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# [<PrefetchDataset shapes: OrderedDict([(x, (None, 2)), (y, (None, 1))]), types: OrderedDict([(x, tf.float64), (y, tf.int32)])>]
# OrderedDict([('sparse_categorical_accuracy', 0.264433), ('loss', 2.172975)])
# OrderedDict([('sparse_categorical_accuracy', 0.5790374), ('loss', 1.3998371)])
# OrderedDict([('sparse_categorical_accuracy', 0.7223144), ('loss', 0.99964)])
# OrderedDict([('sparse_categorical_accuracy', 0.7345928), ('loss', 0.83500236)])
# OrderedDict([('sparse_categorical_accuracy', 0.738825), ('loss', 0.77402616)])
# ##############################
# Monte Carlo Trial #  6
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# [<PrefetchDataset shapes: OrderedDict([(x, (None, 2)), (y, (None, 1))]), types: OrderedDict([(x, tf.float64), (y, tf.int32)])>]
# OrderedDict([('sparse_categorical_accuracy', 0.2418418), ('loss', 2.2595901)])
# OrderedDict([('sparse_categorical_accuracy', 0.4729288), ('loss', 1.5277368)])
# OrderedDict([('sparse_categorical_accuracy', 0.713451), ('loss', 1.0740128)])
# OrderedDict([('sparse_categorical_accuracy', 0.7325832), ('loss', 0.8776474)])
# OrderedDict([('sparse_categorical_accuracy', 0.7379314), ('loss', 0.7924752)])
# ##############################
# Monte Carlo Trial #  7
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# [<PrefetchDataset shapes: OrderedDict([(x, (None, 2)), (y, (None, 1))]), types: OrderedDict([(x, tf.float64), (y, tf.int32)])>]
# OrderedDict([('sparse_categorical_accuracy', 0.3413876), ('loss', 2.1260808)])
# OrderedDict([('sparse_categorical_accuracy', 0.653755), ('loss', 1.3400272)])
# OrderedDict([('sparse_categorical_accuracy', 0.7254318), ('loss', 0.9764757)])
# OrderedDict([('sparse_categorical_accuracy', 0.7367836), ('loss', 0.8321424)])
# OrderedDict([('sparse_categorical_accuracy', 0.740064), ('loss', 0.7716423)])
# ##############################
# Monte Carlo Trial #  8
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# [<PrefetchDataset shapes: OrderedDict([(x, (None, 2)), (y, (None, 1))]), types: OrderedDict([(x, tf.float64), (y, tf.int32)])>]
# OrderedDict([('sparse_categorical_accuracy', 0.1636428), ('loss', 2.1822965)])
# OrderedDict([('sparse_categorical_accuracy', 0.4521182), ('loss', 1.7242378)])
# OrderedDict([('sparse_categorical_accuracy', 0.6792266), ('loss', 1.1804415)])
# OrderedDict([('sparse_categorical_accuracy', 0.7290842), ('loss', 0.9287491)])
# OrderedDict([('sparse_categorical_accuracy', 0.7330484), ('loss', 0.8281928)])
# ##############################
# Monte Carlo Trial #  9
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# [<PrefetchDataset shapes: OrderedDict([(x, (None, 2)), (y, (None, 1))]), types: OrderedDict([(x, tf.float64), (y, tf.int32)])>]
# OrderedDict([('sparse_categorical_accuracy', 0.254377), ('loss', 2.081253)])
# OrderedDict([('sparse_categorical_accuracy', 0.6011562), ('loss', 1.3167019)])
# OrderedDict([('sparse_categorical_accuracy', 0.7205958), ('loss', 0.9596767)])
# OrderedDict([('sparse_categorical_accuracy', 0.7342592), ('loss', 0.8196476)])
# OrderedDict([('sparse_categorical_accuracy', 0.738461), ('loss', 0.76562315)])
# ##############################
# Monte Carlo Trial #  10
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# [<PrefetchDataset shapes: OrderedDict([(x, (None, 2)), (y, (None, 1))]), types: OrderedDict([(x, tf.float64), (y, tf.int32)])>]
# OrderedDict([('sparse_categorical_accuracy', 0.3256062), ('loss', 2.1629262)])
# OrderedDict([('sparse_categorical_accuracy', 0.5856966), ('loss', 1.4337544)])
# OrderedDict([('sparse_categorical_accuracy', 0.7108818), ('loss', 1.0167242)])
# OrderedDict([('sparse_categorical_accuracy', 0.7358454), ('loss', 0.8490776)])
# OrderedDict([('sparse_categorical_accuracy', 0.7395144), ('loss', 0.7786912)])
# ##############################
# 4QAM at Eb/N0= 5 dB
# FedRec trained collaboratively by  10 users
# non-iid  Rayleigh fading
# BER=  0.06530847847461702
# 100
# WARNING:tensorflow:Please add `keras.layers.InputLayer` instead of `keras.Input` to Sequential model. `keras.Input` is intended to be used by Functional model.
# WARNING:tensorflow:Please add `keras.layers.InputLayer` instead of `keras.Input` to Sequential model. `keras.Input` is intended to be used by Functional model.
# WARNING:tensorflow:Please add `keras.layers.InputLayer` instead of `keras.Input` to Sequential model. `keras.Input` is intended to be used by Functional model.
# WARNING:tensorflow:Please add `keras.layers.InputLayer` instead of `keras.Input` to Sequential model. `keras.Input` is intended to be used by Functional model.
# WARNING:tensorflow:Please add `keras.layers.InputLayer` instead of `keras.Input` to Sequential model. `keras.Input` is intended to be used by Functional model.
# WARNING:tensorflow:Please add `keras.layers.InputLayer` instead of `keras.Input` to Sequential model. `keras.Input` is intended to be used by Functional model.
# WARNING:tensorflow:Please add `keras.layers.InputLayer` instead of `keras.Input` to Sequential model. `keras.Input` is intended to be used by Functional model.
# WARNING:tensorflow:Please add `keras.layers.InputLayer` instead of `keras.Input` to Sequential model. `keras.Input` is intended to be used by Functional model.
# WARNING:tensorflow:Please add `keras.layers.InputLayer` instead of `keras.Input` to Sequential model. `keras.Input` is intended to be used by Functional model.
# WARNING:tensorflow:Please add `keras.layers.InputLayer` instead of `keras.Input` to Sequential model. `keras.Input` is intended to be used by Functional model.
# WARNING:tensorflow:Please add `keras.layers.InputLayer` instead of `keras.Input` to Sequential model. `keras.Input` is intended to be used by Functional model.
# WARNING:tensorflow:Please add `keras.layers.InputLayer` instead of `keras.Input` to Sequential model. `keras.Input` is intended to be used by Functional model.
# <tensorflow_federated.python.core.impl.computation.computation_impl.ComputationImpl object at 0x7f61cbe2b250>
# ##############################
# Monte Carlo Trial #  1
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# [<PrefetchDataset shapes: OrderedDict([(x, (None, 2)), (y, (None, 1))]), types: OrderedDict([(x, tf.float64), (y, tf.int32)])>]
# OrderedDict([('sparse_categorical_accuracy', 0.059439), ('loss', 2.8053253)])
# OrderedDict([('sparse_categorical_accuracy', 0.057155), ('loss', 2.7556863)])
# OrderedDict([('sparse_categorical_accuracy', 0.0869684), ('loss', 2.7149243)])
# OrderedDict([('sparse_categorical_accuracy', 0.1597468), ('loss', 2.664553)])
# OrderedDict([('sparse_categorical_accuracy', 0.1388612), ('loss', 2.6082072)])
# ##############################
# Monte Carlo Trial #  2
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# ...
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# [<PrefetchDataset shapes: OrderedDict([(x, (None, 2)), (y, (None, 1))]), types: OrderedDict([(x, tf.float64), (y, tf.int32)])>]
# OrderedDict([('sparse_categorical_accuracy', 0.1300616), ('loss', 2.7244415)])
# OrderedDict([('sparse_categorical_accuracy', 0.1539382), ('loss', 2.6732993)])
# OrderedDict([('sparse_categorical_accuracy', 0.1970188), ('loss', 2.6155293)])
# OrderedDict([('sparse_categorical_accuracy', 0.1996756), ('loss', 2.5474343)])
# OrderedDict([('sparse_categorical_accuracy', 0.2308528), ('loss', 2.4781263)])
# ##############################
# Monte Carlo Trial #  6
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# [<PrefetchDataset shapes: OrderedDict([(x, (None, 2)), (y, (None, 1))]), types: OrderedDict([(x, tf.float64), (y, tf.int32)])>]
# OrderedDict([('sparse_categorical_accuracy', 0.1925378), ('loss', 2.6970465)])
# OrderedDict([('sparse_categorical_accuracy', 0.1841162), ('loss', 2.6277764)])
# OrderedDict([('sparse_categorical_accuracy', 0.2313958), ('loss', 2.5490034)])
# OrderedDict([('sparse_categorical_accuracy', 0.2478706), ('loss', 2.4660573)])
# OrderedDict([('sparse_categorical_accuracy', 0.2493976), ('loss', 2.3813157)])
# ##############################
# Monte Carlo Trial #  7
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
