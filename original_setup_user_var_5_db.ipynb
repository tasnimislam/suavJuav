# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install tensorflow-federated
# Out:
# Collecting tensorflow-federated
#   Downloading tensorflow_federated-0.19.0-py2.py3-none-any.whl (602 kB)
#      |████████████████████████████████| 602 kB 4.9 MB/s
# Collecting tqdm~=4.28.1
#   Downloading tqdm-4.28.1-py2.py3-none-any.whl (45 kB)
#      |████████████████████████████████| 45 kB 3.4 MB/s
# Requirement already satisfied: portpicker~=1.3.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow-federated) (1.3.9)
# Collecting tensorflow-privacy~=0.5.0
#   Downloading tensorflow_privacy-0.5.2-py3-none-any.whl (192 kB)
#      |████████████████████████████████| 192 kB 9.4 MB/s
# Requirement already satisfied: tensorflow~=2.5.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow-federated) (2.5.0)
# Collecting cachetools~=3.1.1
#   Downloading cachetools-3.1.1-py2.py3-none-any.whl (11 kB)
# Collecting semantic-version~=2.8.5
#   Downloading semantic_version-2.8.5-py2.py3-none-any.whl (15 kB)
# Collecting attrs~=19.3.0
#   Downloading attrs-19.3.0-py2.py3-none-any.whl (39 kB)
# Requirement already satisfied: retrying~=1.3.3 in /usr/local/lib/python3.7/dist-packages (from tensorflow-federated) (1.3.3)
# Requirement already satisfied: dm-tree~=0.1.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow-federated) (0.1.6)
# Requirement already satisfied: jaxlib~=0.1.55 in /usr/local/lib/python3.7/dist-packages (from tensorflow-federated) (0.1.69+cuda110)
# Requirement already satisfied: jax~=0.2.8 in /usr/local/lib/python3.7/dist-packages (from tensorflow-federated) (0.2.17)
# Requirement already satisfied: grpcio~=1.34.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow-federated) (1.34.1)
# Requirement already satisfied: numpy~=1.19.2 in /usr/local/lib/python3.7/dist-packages (from tensorflow-federated) (1.19.5)
# Collecting tensorflow-model-optimization~=0.5.0
#   Downloading tensorflow_model_optimization-0.5.0-py2.py3-none-any.whl (172 kB)
#      |████████████████████████████████| 172 kB 11.4 MB/s
# Requirement already satisfied: absl-py~=0.10 in /usr/local/lib/python3.7/dist-packages (from tensorflow-federated) (0.12.0)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from absl-py~=0.10->tensorflow-federated) (1.15.0)
# Requirement already satisfied: opt-einsum in /usr/local/lib/python3.7/dist-packages (from jax~=0.2.8->tensorflow-federated) (3.3.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/dist-packages (from jaxlib~=0.1.55->tensorflow-federated) (1.4.1)
# Requirement already satisfied: flatbuffers<3.0,>=1.12 in /usr/local/lib/python3.7/dist-packages (from jaxlib~=0.1.55->tensorflow-federated) (1.12)
# Requirement already satisfied: keras-nightly~=2.5.0.dev in /usr/local/lib/python3.7/dist-packages (from tensorflow~=2.5.0->tensorflow-federated) (2.5.0.dev2021032900)
# Requirement already satisfied: termcolor~=1.1.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow~=2.5.0->tensorflow-federated) (1.1.0)
# Requirement already satisfied: tensorboard~=2.5 in /usr/local/lib/python3.7/dist-packages (from tensorflow~=2.5.0->tensorflow-federated) (2.5.0)
# Requirement already satisfied: protobuf>=3.9.2 in /usr/local/lib/python3.7/dist-packages (from tensorflow~=2.5.0->tensorflow-federated) (3.17.3)
# Requirement already satisfied: wheel~=0.35 in /usr/local/lib/python3.7/dist-packages (from tensorflow~=2.5.0->tensorflow-federated) (0.37.0)
# Requirement already satisfied: keras-preprocessing~=1.1.2 in /usr/local/lib/python3.7/dist-packages (from tensorflow~=2.5.0->tensorflow-federated) (1.1.2)
# Requirement already satisfied: google-pasta~=0.2 in /usr/local/lib/python3.7/dist-packages (from tensorflow~=2.5.0->tensorflow-federated) (0.2.0)
# Requirement already satisfied: typing-extensions~=3.7.4 in /usr/local/lib/python3.7/dist-packages (from tensorflow~=2.5.0->tensorflow-federated) (3.7.4.3)
# Requirement already satisfied: wrapt~=1.12.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow~=2.5.0->tensorflow-federated) (1.12.1)
# Requirement already satisfied: astunparse~=1.6.3 in /usr/local/lib/python3.7/dist-packages (from tensorflow~=2.5.0->tensorflow-federated) (1.6.3)
# Requirement already satisfied: h5py~=3.1.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow~=2.5.0->tensorflow-federated) (3.1.0)
# Requirement already satisfied: gast==0.4.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow~=2.5.0->tensorflow-federated) (0.4.0)
# Requirement already satisfied: tensorflow-estimator<2.6.0,>=2.5.0rc0 in /usr/local/lib/python3.7/dist-packages (from tensorflow~=2.5.0->tensorflow-federated) (2.5.0)
# Requirement already satisfied: cached-property in /usr/local/lib/python3.7/dist-packages (from h5py~=3.1.0->tensorflow~=2.5.0->tensorflow-federated) (1.5.2)
# Requirement already satisfied: google-auth<2,>=1.6.3 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.5->tensorflow~=2.5.0->tensorflow-federated) (1.34.0)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.5->tensorflow~=2.5.0->tensorflow-federated) (0.6.1)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.5->tensorflow~=2.5.0->tensorflow-federated) (1.8.0)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.5->tensorflow~=2.5.0->tensorflow-federated) (2.23.0)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.5->tensorflow~=2.5.0->tensorflow-federated) (0.4.5)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.5->tensorflow~=2.5.0->tensorflow-federated) (3.3.4)
# Requirement already satisfied: werkzeug>=0.11.15 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.5->tensorflow~=2.5.0->tensorflow-federated) (1.0.1)
# Requirement already satisfied: setuptools>=41.0.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.5->tensorflow~=2.5.0->tensorflow-federated) (57.2.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.7/dist-packages (from google-auth<2,>=1.6.3->tensorboard~=2.5->tensorflow~=2.5.0->tensorflow-federated) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.7/dist-packages (from google-auth<2,>=1.6.3->tensorboard~=2.5->tensorflow~=2.5.0->tensorflow-federated) (4.7.2)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.7/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard~=2.5->tensorflow~=2.5.0->tensorflow-federated) (1.3.0)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from markdown>=2.6.8->tensorboard~=2.5->tensorflow~=2.5.0->tensorflow-federated) (4.6.3)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.7/dist-packages (from pyasn1-modules>=0.2.1->google-auth<2,>=1.6.3->tensorboard~=2.5->tensorflow~=2.5.0->tensorflow-federated) (0.4.8)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard~=2.5->tensorflow~=2.5.0->tensorflow-federated) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard~=2.5->tensorflow~=2.5.0->tensorflow-federated) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard~=2.5->tensorflow~=2.5.0->tensorflow-federated) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard~=2.5->tensorflow~=2.5.0->tensorflow-federated) (2021.5.30)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.7/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard~=2.5->tensorflow~=2.5.0->tensorflow-federated) (3.1.1)
# Requirement already satisfied: mpmath in /usr/local/lib/python3.7/dist-packages (from tensorflow-privacy~=0.5.0->tensorflow-federated) (1.2.1)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->markdown>=2.6.8->tensorboard~=2.5->tensorflow~=2.5.0->tensorflow-federated) (3.5.0)
# Installing collected packages: cachetools, tqdm, tensorflow-privacy, tensorflow-model-optimization, semantic-version, attrs, tensorflow-federated
#   Attempting uninstall: cachetools
#     Found existing installation: cachetools 4.2.2
#     Uninstalling cachetools-4.2.2:
#       Successfully uninstalled cachetools-4.2.2
#   Attempting uninstall: tqdm
#     Found existing installation: tqdm 4.62.0
#     Uninstalling tqdm-4.62.0:
#       Successfully uninstalled tqdm-4.62.0
#   Attempting uninstall: attrs
#     Found existing installation: attrs 21.2.0
#     Uninstalling attrs-21.2.0:
#       Successfully uninstalled attrs-21.2.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# spacy 2.2.4 requires tqdm<5.0.0,>=4.38.0, but you have tqdm 4.28.1 which is incompatible.
# pymc3 3.11.2 requires cachetools>=4.2.1, but you have cachetools 3.1.1 which is incompatible.
# panel 0.12.1 requires tqdm>=4.48.0, but you have tqdm 4.28.1 which is incompatible.
# fbprophet 0.7.1 requires tqdm>=4.36.1, but you have tqdm 4.28.1 which is incompatible.
# datascience 0.10.6 requires folium==0.2.1, but you have folium 0.8.3 which is incompatible.
# Successfully installed attrs-19.3.0 cachetools-3.1.1 semantic-version-2.8.5 tensorflow-federated-0.19.0 tensorflow-model-optimization-0.5.0 tensorflow-privacy-0.5.2 tqdm-4.28.1

# %%
import os
import collections
import numpy as np
import scipy.io as sio
import tensorflow as tf
import tensorflow_federated as tff
import matplotlib.pyplot as plt
from keras import backend as K 
from keras.layers import Layer
import tensorflow_probability as tfp
tfd = tfp.distributions

################################ Functions ################################

def dc_compensation(z):
    """
    Function to estimate and remove DC impairments in the IQ branch
    Parameters:
    z: DC impaired signal sequence (numpy format)
    Returns:
    v: DC removed signal sequence
    """
    iDCest=np.mean(z[:, 0]) # estimated DC on I branch
    qDCest=np.mean(z[:, 1]) # estimated DC on I branch
    v=z-(iDCest+1j*qDCest) # remove estimated DCs
    return v

def blind_iq_compensation(z):
    """
    Function to estimate and compensate IQ impairments for the
    single-branch IQ impairment model
    Parameters:
    z: DC impaired signal sequence (numpy format)
    Returns:
    y: IQ imbalance compensated signal sequence
    """
    I=z[:, 0];Q=z[:, 1]
    theta1=(-1)*np.mean(np.sign(I)*Q)
    theta2=np.mean(abs(I)); theta3=np.mean(abs(Q))
    c1=theta1/theta2
    c2=np.sqrt((theta3**2-theta1**2)/theta2**2)
    x_u2 = I +1j*(c1*I+Q)/c2
    return x_u2


def usergen(x, y, iid, N0):
    if iid==True:
        sigma = 1 # i.i.d. user fading 
    else:
        sigma = np.random.uniform(low=0.5, high=1.5, size=None) #non-i.i.d. user fading
        
    h = np.random.rayleigh(scale=sigma, size=(x.shape[0],1))
    hIQ=np.concatenate((h,h),axis=1)
    x_u = np.multiply(hIQ,x)+ np.random.normal(0, np.sqrt(N0)/2, x.shape) # Channel-distorted noisy features
    y_u = np.real(y) # Labels
    # print(y_u)
    # y_u = np.interp(y_u, (y_u.min(), y_u.max()), (0, 1))
    D_u = tf.data.Dataset.from_tensor_slices((list(x_u),list(y_u.astype(int))))

    return D_u


def testgen(x, y, iid, N0):
    if iid==True:
        h = np.random.rayleigh(scale=1, size=(x.shape[0],1)) # i.i.d. test fading 
    else:
        h = np.random.rayleigh(scale=np.random.uniform(low=0.5, high=1.5, size=(x.shape[0],1)), size=(x.shape[0],1)) # non-i.i.d. user fading
    hIQ = np.concatenate((h,h),axis=1)
    x_test = np.multiply(hIQ,x) + np.random.normal(0, np.sqrt(N0)/2, x.shape) # Channel-distorted noisy features
    y_test = np.real(y) # Labels
    # print(y_test)
    # y_test = np.interp(y_test, (y_test.min(), y_test.max()), (0, 1))

    dataset_test = tf.data.Dataset.from_tensor_slices((list(x_test),list(y_test.astype(int))))
    
    return dataset_test


def preprocess(dataset):
    EPOCH = 5 # Number of local epochs for each aggragation round
    AGGREGATION_ROUND = 5 # Number of federated aggregation rounds
    BATCH_SIZE = 1000
    SHUFFLE_BUFFER = 20
    PREFETCH_BUFFER = 10
    def batch_format_fn(element1,element2):
        return collections.OrderedDict(
            x=tf.reshape(element1, [-1, 2]),
            y=tf.reshape(element2, [-1, 1]))
    return dataset.repeat(EPOCH).shuffle(SHUFFLE_BUFFER).batch(
        BATCH_SIZE).map(batch_format_fn).prefetch(PREFETCH_BUFFER)

# %%
class CompensateLayer(Layer): 
   def __init__(self, output_dim, **kwargs): 
      self.output_dim = output_dim 
      super(CompensateLayer, self).__init__(**kwargs) 
   def build(self, input_shape): 
    self.kernel = self.add_weight(name = 'kernel', 
      shape = (input_shape[1], self.output_dim), 
      initializer = 'normal', trainable = True) 
    super(CompensateLayer, self).build(input_shape)   
   def call(self, input_data): 
     x = K.dot(input_data, self.kernel)
     return x - K.mean(x, axis = [0, 1])
   def compute_output_shape(self, input_shape): return (input_shape[0], self.output_dim)

# %%
def create_keras_model():
    Q = 4 
    M = 2**Q # 16QAM modulation
    Es = 10 # Average symbol energy
    model = tf.keras.models.Sequential()
    model.add(tf.keras.layers.Input(shape=(2,)))
    # model.add(CompensateLayer(2, input_shape = (2, )))
    model.add(tf.keras.layers.Dense(M, activation=tf.keras.activations.softmax))
    return model

# %%
def model_fn():
  keras_model = create_keras_model()
  return tff.learning.from_keras_model(
      keras_model,
      input_spec=preprocessed_example_dataset.element_spec,
      loss=tf.keras.losses.SparseCategoricalCrossentropy(),
      metrics=[tf.keras.metrics.SparseCategoricalAccuracy()])

# %%
# %cd "/content/drive/MyDrive/Tasnim_BUET/11 august/fedrec_moderation"
def train(user_g, snr_g, iid_g):
    os.environ["CUDA_VISIBLE_DEVICES"] = "0"

    MC = 10 # Number of Monte Carlo trials
    iid = iid_g # set to False to simulate non-iid user fading 

    ### Modulation Parameters
    Q = 4 
    M = 2**Q # 16QAM modulation
    Es = 10 # Average symbol energy

    ### Noise Parameters
    EbN0_dB = snr_g # SNR per bit (dB)
    EsN0_dB = EbN0_dB + 10*np.log10(Q) # SNR per symbol (dB)
    N0 = Es/10**(EsN0_dB/10)

    ### FedRec Training Parameters
    U = user_g # Number of wireless users taking part in federated training
    EPOCH = 5 # Number of local epochs for each aggragation round
    AGGREGATION_ROUND = 5 # Number of federated aggregation rounds
    BATCH_SIZE = 1000 
    SHUFFLE_BUFFER = 20
    PREFETCH_BUFFER = 10

    ### Load QAM I/Q Symbols
    TRAIN = sio.loadmat('TRAIN_fedrec.mat')
    Train = TRAIN['TRAIN']
    TEST = sio.loadmat('TEST_fedrec.mat')
    Test = TEST['TEST']


    ### Generate Real-valued Train/Test Features/Labels
    N_T = int(Train.shape[0]/U) # Size of local user datasets 
    x_train = np.zeros((N_T,2))
    x_train[:,0] = np.real(Train[0:N_T,0])
    x_train[:,1] = np.imag(Train[0:N_T,0])
    y_train = Train[0:N_T,1]-1

    x_test = np.zeros((Test.shape[0],2))
    x_test[:,0] = np.real(Test[:,0])
    x_test[:,1] = np.imag(Test[:,0])
    y_test = Test[:,1]-1


    example_dataset = usergen(x_train, y_train, iid, N0)
    # print(f"uplink dataset: U_U: {len(example_dataset)}")
    preprocessed_example_dataset=preprocess(example_dataset)
    example_element = next(iter((preprocessed_example_dataset)))

    def model_fn():
        keras_model = create_keras_model()
        return tff.learning.from_keras_model(
            keras_model,
            input_spec=preprocessed_example_dataset.element_spec,
            loss=tf.keras.losses.SparseCategoricalCrossentropy(),
            metrics=[tf.keras.metrics.SparseCategoricalAccuracy()])


    iterative_process = tff.learning.build_federated_averaging_process(
        model_fn,
        client_optimizer_fn=lambda: tf.keras.optimizers.Adam(learning_rate=0.05),
        server_optimizer_fn=lambda: tf.keras.optimizers.SGD(learning_rate=1.0))

    evaluation = tff.learning.build_federated_evaluation(model_fn)
    print(evaluation)


    BER = 0
    for i in range(MC):
        
        print('##############################')
        print('Monte Carlo Trial # ', i+1)
        
        ### Generate Federated User Datasets
        federated_train_data=[]
        for u in range(U):
            D_u = usergen(x_train, y_train, iid, N0) ### Generate Local Dataset at user u
            # print(f"downlink dataset: D_U: {len(D_u)}")
            federated_train_data.append(preprocess(D_u))
            print(D_u)
                
        ### Generate Test Dataset
        test_dataset = testgen(x_test, y_test, iid, N0)
        federated_test_data=[preprocess(test_dataset)]
        print(federated_test_data)
        
        ### Federated Training
        state = iterative_process.initialize()
        for n in range(AGGREGATION_ROUND):
            state, metrics = iterative_process.next(state, federated_train_data)
            # print(str(metrics))
            
            ### Evaluate the Model
            test_metrics = evaluation(state.model, federated_test_data)
            print(str(test_metrics))
        
        BER = BER + (1-test_metrics['sparse_categorical_accuracy'])/(Q*MC)

        
    print('##############################')
    print('4QAM at Eb/N0=', EbN0_dB, 'dB')
    print('FedRec trained collaboratively by ', U, 'users')
    if iid==True:
            iidstr = 'iid' 
    else:
            iidstr = 'non-iid'
    print(iidstr, ' Rayleigh fading')
    print('BER= ', BER)

    return BER
# Out:
# /content/drive/MyDrive/Tasnim_BUET/11 august/fedrec_moderation

# %%
# !pip install nest_asyncio
import nest_asyncio
nest_asyncio.apply()
# Out:
# Requirement already satisfied: nest_asyncio in /usr/local/lib/python3.7/dist-packages (1.5.1)

# %%
def main():
    ber = []
    iid = False
    dataset_setup = 'compensate in model'
    # %cd "/content/drive/MyDrive/Tasnim_BUET/11 august/fedrec_moderation"
    for i in [1, 5, 10, 100, 1000]:
      print(i)
      x = train(i, 5, iid)
      ber.append(x)
      with open(f'user_change_{iid}_dataset_setup_{dataset_setup}_5db.txt', 'a+') as f:
        f.write(str(x) + '\n')
    with open(f'user_change_{iid}_dataset_setup_{dataset_setup}_5db.txt', 'a+') as f:
        f.write(str(ber) + '\n')
main()
# Out:
# /content/drive/MyDrive/Tasnim_BUET/11 august/fedrec_moderation
# 1
# WARNING:tensorflow:Please add `keras.layers.InputLayer` instead of `keras.Input` to Sequential model. `keras.Input` is intended to be used by Functional model.
# WARNING:tensorflow:Please add `keras.layers.InputLayer` instead of `keras.Input` to Sequential model. `keras.Input` is intended to be used by Functional model.
# WARNING:tensorflow:Please add `keras.layers.InputLayer` instead of `keras.Input` to Sequential model. `keras.Input` is intended to be used by Functional model.
# WARNING:tensorflow:Please add `keras.layers.InputLayer` instead of `keras.Input` to Sequential model. `keras.Input` is intended to be used by Functional model.
# WARNING:tensorflow:Please add `keras.layers.InputLayer` instead of `keras.Input` to Sequential model. `keras.Input` is intended to be used by Functional model.
# WARNING:tensorflow:Please add `keras.layers.InputLayer` instead of `keras.Input` to Sequential model. `keras.Input` is intended to be used by Functional model.
# <tensorflow_federated.python.core.impl.computation.computation_impl.ComputationImpl object at 0x7fb52d429b50>
# ##############################
# Monte Carlo Trial #  1
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# [<PrefetchDataset shapes: OrderedDict([(x, (None, 2)), (y, (None, 1))]), types: OrderedDict([(x, tf.float64), (y, tf.int32)])>]
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/tensorflow_federated/python/core/impl/compiler/tensorflow_computation_transformations.py:60: extract_sub_graph (from tensorflow.python.framework.graph_util_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.compat.v1.graph_util.extract_sub_graph`
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/tensorflow_federated/python/core/impl/compiler/tensorflow_computation_transformations.py:60: extract_sub_graph (from tensorflow.python.framework.graph_util_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.compat.v1.graph_util.extract_sub_graph`
# OrderedDict([('sparse_categorical_accuracy', 0.662726), ('loss', 1.0568018)])
# OrderedDict([('sparse_categorical_accuracy', 0.700687), ('loss', 0.9206058)])
# OrderedDict([('sparse_categorical_accuracy', 0.702192), ('loss', 0.9036167)])
# OrderedDict([('sparse_categorical_accuracy', 0.70247), ('loss', 0.8986059)])
# OrderedDict([('sparse_categorical_accuracy', 0.702547), ('loss', 0.896891)])
# ##############################
# Monte Carlo Trial #  2
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# [<PrefetchDataset shapes: OrderedDict([(x, (None, 2)), (y, (None, 1))]), types: OrderedDict([(x, tf.float64), (y, tf.int32)])>]
# OrderedDict([('sparse_categorical_accuracy', 0.730234), ('loss', 0.9986422)])
# OrderedDict([('sparse_categorical_accuracy', 0.741493), ('loss', 0.7875547)])
# OrderedDict([('sparse_categorical_accuracy', 0.744462), ('loss', 0.74179876)])
# OrderedDict([('sparse_categorical_accuracy', 0.745372), ('loss', 0.72709596)])
# OrderedDict([('sparse_categorical_accuracy', 0.74583), ('loss', 0.721457)])
# ##############################
# Monte Carlo Trial #  3
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# [<PrefetchDataset shapes: OrderedDict([(x, (None, 2)), (y, (None, 1))]), types: OrderedDict([(x, tf.float64), (y, tf.int32)])>]
# OrderedDict([('sparse_categorical_accuracy', 0.695595), ('loss', 1.041148)])
# OrderedDict([('sparse_categorical_accuracy', 0.725869), ('loss', 0.82216346)])
# OrderedDict([('sparse_categorical_accuracy', 0.727252), ('loss', 0.7897557)])
# OrderedDict([('sparse_categorical_accuracy', 0.727723), ('loss', 0.7794697)])
# OrderedDict([('sparse_categorical_accuracy', 0.727453), ('loss', 0.77647626)])
# ##############################
# Monte Carlo Trial #  4
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# [<PrefetchDataset shapes: OrderedDict([(x, (None, 2)), (y, (None, 1))]), types: OrderedDict([(x, tf.float64), (y, tf.int32)])>]
# OrderedDict([('sparse_categorical_accuracy', 0.732233), ('loss', 1.0148335)])
# OrderedDict([('sparse_categorical_accuracy', 0.741145), ('loss', 0.7836091)])
# OrderedDict([('sparse_categorical_accuracy', 0.743624), ('loss', 0.74159825)])
# OrderedDict([('sparse_categorical_accuracy', 0.744269), ('loss', 0.72914904)])
# OrderedDict([('sparse_categorical_accuracy', 0.744506), ('loss', 0.72443676)])
# ##############################
# Monte Carlo Trial #  5
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# [<PrefetchDataset shapes: OrderedDict([(x, (None, 2)), (y, (None, 1))]), types: OrderedDict([(x, tf.float64), (y, tf.int32)])>]
# OrderedDict([('sparse_categorical_accuracy', 0.678947), ('loss', 1.1062558)])
# OrderedDict([('sparse_categorical_accuracy', 0.708825), ('loss', 0.8557609)])
# OrderedDict([('sparse_categorical_accuracy', 0.718581), ('loss', 0.795401)])
# OrderedDict([('sparse_categorical_accuracy', 0.722909), ('loss', 0.77281886)])
# OrderedDict([('sparse_categorical_accuracy', 0.725296), ('loss', 0.7622481)])
# ##############################
# Monte Carlo Trial #  6
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# [<PrefetchDataset shapes: OrderedDict([(x, (None, 2)), (y, (None, 1))]), types: OrderedDict([(x, tf.float64), (y, tf.int32)])>]
# OrderedDict([('sparse_categorical_accuracy', 0.732755), ('loss', 1.0165484)])
# OrderedDict([('sparse_categorical_accuracy', 0.741237), ('loss', 0.786685)])
# OrderedDict([('sparse_categorical_accuracy', 0.743343), ('loss', 0.7430537)])
# OrderedDict([('sparse_categorical_accuracy', 0.74422), ('loss', 0.7281719)])
# OrderedDict([('sparse_categorical_accuracy', 0.744564), ('loss', 0.7222469)])
# ##############################
# Monte Carlo Trial #  7
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# [<PrefetchDataset shapes: OrderedDict([(x, (None, 2)), (y, (None, 1))]), types: OrderedDict([(x, tf.float64), (y, tf.int32)])>]
# OrderedDict([('sparse_categorical_accuracy', 0.672986), ('loss', 1.1141824)])
# OrderedDict([('sparse_categorical_accuracy', 0.704092), ('loss', 0.8625212)])
# OrderedDict([('sparse_categorical_accuracy', 0.715179), ('loss', 0.8020324)])
# OrderedDict([('sparse_categorical_accuracy', 0.719156), ('loss', 0.78103566)])
# OrderedDict([('sparse_categorical_accuracy', 0.72065), ('loss', 0.77293175)])
# ##############################
# Monte Carlo Trial #  8
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# [<PrefetchDataset shapes: OrderedDict([(x, (None, 2)), (y, (None, 1))]), types: OrderedDict([(x, tf.float64), (y, tf.int32)])>]
# OrderedDict([('sparse_categorical_accuracy', 0.68504), ('loss', 1.095382)])
# OrderedDict([('sparse_categorical_accuracy', 0.711725), ('loss', 0.8502428)])
# OrderedDict([('sparse_categorical_accuracy', 0.721822), ('loss', 0.7913776)])
# OrderedDict([('sparse_categorical_accuracy', 0.725302), ('loss', 0.77160573)])
# OrderedDict([('sparse_categorical_accuracy', 0.726973), ('loss', 0.76324105)])
# ##############################
# Monte Carlo Trial #  9
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# [<PrefetchDataset shapes: OrderedDict([(x, (None, 2)), (y, (None, 1))]), types: OrderedDict([(x, tf.float64), (y, tf.int32)])>]
# OrderedDict([('sparse_categorical_accuracy', 0.70247), ('loss', 1.0332432)])
# OrderedDict([('sparse_categorical_accuracy', 0.723358), ('loss', 0.8230311)])
# OrderedDict([('sparse_categorical_accuracy', 0.73053), ('loss', 0.7718177)])
# OrderedDict([('sparse_categorical_accuracy', 0.73307), ('loss', 0.7536295)])
# OrderedDict([('sparse_categorical_accuracy', 0.734583), ('loss', 0.7454575)])
# ##############################
# Monte Carlo Trial #  10
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# [<PrefetchDataset shapes: OrderedDict([(x, (None, 2)), (y, (None, 1))]), types: OrderedDict([(x, tf.float64), (y, tf.int32)])>]
# OrderedDict([('sparse_categorical_accuracy', 0.720696), ('loss', 0.9959137)])
# OrderedDict([('sparse_categorical_accuracy', 0.7311), ('loss', 0.80537534)])
# OrderedDict([('sparse_categorical_accuracy', 0.731674), ('loss', 0.77356076)])
# OrderedDict([('sparse_categorical_accuracy', 0.732082), ('loss', 0.7631203)])
# OrderedDict([('sparse_categorical_accuracy', 0.731881), ('loss', 0.7594514)])
# ##############################
# 4QAM at Eb/N0= 5 dB
# FedRec trained collaboratively by  1 users
# non-iid  Rayleigh fading
# BER=  0.06739292293787003
# 5
# WARNING:tensorflow:Please add `keras.layers.InputLayer` instead of `keras.Input` to Sequential model. `keras.Input` is intended to be used by Functional model.
# WARNING:tensorflow:Please add `keras.layers.InputLayer` instead of `keras.Input` to Sequential model. `keras.Input` is intended to be used by Functional model.
# WARNING:tensorflow:Please add `keras.layers.InputLayer` instead of `keras.Input` to Sequential model. `keras.Input` is intended to be used by Functional model.
# WARNING:tensorflow:Please add `keras.layers.InputLayer` instead of `keras.Input` to Sequential model. `keras.Input` is intended to be used by Functional model.
# WARNING:tensorflow:Please add `keras.layers.InputLayer` instead of `keras.Input` to Sequential model. `keras.Input` is intended to be used by Functional model.
# WARNING:tensorflow:Please add `keras.layers.InputLayer` instead of `keras.Input` to Sequential model. `keras.Input` is intended to be used by Functional model.
# WARNING:tensorflow:Please add `keras.layers.InputLayer` instead of `keras.Input` to Sequential model. `keras.Input` is intended to be used by Functional model.
# WARNING:tensorflow:Please add `keras.layers.InputLayer` instead of `keras.Input` to Sequential model. `keras.Input` is intended to be used by Functional model.
# WARNING:tensorflow:Please add `keras.layers.InputLayer` instead of `keras.Input` to Sequential model. `keras.Input` is intended to be used by Functional model.
# WARNING:tensorflow:Please add `keras.layers.InputLayer` instead of `keras.Input` to Sequential model. `keras.Input` is intended to be used by Functional model.
# WARNING:tensorflow:Please add `keras.layers.InputLayer` instead of `keras.Input` to Sequential model. `keras.Input` is intended to be used by Functional model.
# WARNING:tensorflow:Please add `keras.layers.InputLayer` instead of `keras.Input` to Sequential model. `keras.Input` is intended to be used by Functional model.
# <tensorflow_federated.python.core.impl.computation.computation_impl.ComputationImpl object at 0x7fb505d2fad0>
# ##############################
# Monte Carlo Trial #  1
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# [<PrefetchDataset shapes: OrderedDict([(x, (None, 2)), (y, (None, 1))]), types: OrderedDict([(x, tf.float64), (y, tf.int32)])>]
# OrderedDict([('sparse_categorical_accuracy', 0.531615), ('loss', 1.5989697)])
# OrderedDict([('sparse_categorical_accuracy', 0.710118), ('loss', 1.1509527)])
# OrderedDict([('sparse_categorical_accuracy', 0.72747), ('loss', 0.9850317)])
# OrderedDict([('sparse_categorical_accuracy', 0.729987), ('loss', 0.905167)])
# OrderedDict([('sparse_categorical_accuracy', 0.730939), ('loss', 0.8616771)])
# ##############################
# Monte Carlo Trial #  2
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# [<PrefetchDataset shapes: OrderedDict([(x, (None, 2)), (y, (None, 1))]), types: OrderedDict([(x, tf.float64), (y, tf.int32)])>]
# OrderedDict([('sparse_categorical_accuracy', 0.479293), ('loss', 1.5556109)])
# OrderedDict([('sparse_categorical_accuracy', 0.718172), ('loss', 1.1490217)])
# OrderedDict([('sparse_categorical_accuracy', 0.721144), ('loss', 1.0091822)])
# OrderedDict([('sparse_categorical_accuracy', 0.724562), ('loss', 0.9301398)])
# OrderedDict([('sparse_categorical_accuracy', 0.72838), ('loss', 0.878542)])
# ##############################
# Monte Carlo Trial #  3
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# [<PrefetchDataset shapes: OrderedDict([(x, (None, 2)), (y, (None, 1))]), types: OrderedDict([(x, tf.float64), (y, tf.int32)])>]
# OrderedDict([('sparse_categorical_accuracy', 0.527595), ('loss', 1.5696065)])
# OrderedDict([('sparse_categorical_accuracy', 0.727266), ('loss', 1.1607354)])
# OrderedDict([('sparse_categorical_accuracy', 0.73187), ('loss', 0.9935014)])
# OrderedDict([('sparse_categorical_accuracy', 0.735067), ('loss', 0.9084513)])
# OrderedDict([('sparse_categorical_accuracy', 0.737727), ('loss', 0.856874)])
# ##############################
# Monte Carlo Trial #  4
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# [<PrefetchDataset shapes: OrderedDict([(x, (None, 2)), (y, (None, 1))]), types: OrderedDict([(x, tf.float64), (y, tf.int32)])>]
# OrderedDict([('sparse_categorical_accuracy', 0.566071), ('loss', 1.631856)])
# OrderedDict([('sparse_categorical_accuracy', 0.721768), ('loss', 1.1709989)])
# OrderedDict([('sparse_categorical_accuracy', 0.731638), ('loss', 0.992678)])
# OrderedDict([('sparse_categorical_accuracy', 0.734587), ('loss', 0.9059333)])
# OrderedDict([('sparse_categorical_accuracy', 0.737013), ('loss', 0.85457)])
# ##############################
# Monte Carlo Trial #  5
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# [<PrefetchDataset shapes: OrderedDict([(x, (None, 2)), (y, (None, 1))]), types: OrderedDict([(x, tf.float64), (y, tf.int32)])>]
# OrderedDict([('sparse_categorical_accuracy', 0.480697), ('loss', 1.6521151)])
# OrderedDict([('sparse_categorical_accuracy', 0.721374), ('loss', 1.1941997)])
# OrderedDict([('sparse_categorical_accuracy', 0.729365), ('loss', 1.0178227)])
# OrderedDict([('sparse_categorical_accuracy', 0.73165), ('loss', 0.9290992)])
# OrderedDict([('sparse_categorical_accuracy', 0.734384), ('loss', 0.8775275)])
# ##############################
# Monte Carlo Trial #  6
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# [<PrefetchDataset shapes: OrderedDict([(x, (None, 2)), (y, (None, 1))]), types: OrderedDict([(x, tf.float64), (y, tf.int32)])>]
# OrderedDict([('sparse_categorical_accuracy', 0.470411), ('loss', 1.6005425)])
# OrderedDict([('sparse_categorical_accuracy', 0.726522), ('loss', 1.1438978)])
# OrderedDict([('sparse_categorical_accuracy', 0.733894), ('loss', 0.9796569)])
# OrderedDict([('sparse_categorical_accuracy', 0.736095), ('loss', 0.89967)])
# OrderedDict([('sparse_categorical_accuracy', 0.737537), ('loss', 0.8539558)])
# ##############################
# Monte Carlo Trial #  7
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# [<PrefetchDataset shapes: OrderedDict([(x, (None, 2)), (y, (None, 1))]), types: OrderedDict([(x, tf.float64), (y, tf.int32)])>]
# OrderedDict([('sparse_categorical_accuracy', 0.421401), ('loss', 1.6458961)])
# OrderedDict([('sparse_categorical_accuracy', 0.724292), ('loss', 1.1774358)])
# OrderedDict([('sparse_categorical_accuracy', 0.731337), ('loss', 0.9979797)])
# OrderedDict([('sparse_categorical_accuracy', 0.733938), ('loss', 0.9107513)])
# OrderedDict([('sparse_categorical_accuracy', 0.736248), ('loss', 0.858962)])
# ##############################
# Monte Carlo Trial #  8
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# [<PrefetchDataset shapes: OrderedDict([(x, (None, 2)), (y, (None, 1))]), types: OrderedDict([(x, tf.float64), (y, tf.int32)])>]
# OrderedDict([('sparse_categorical_accuracy', 0.516046), ('loss', 1.5302202)])
# OrderedDict([('sparse_categorical_accuracy', 0.713139), ('loss', 1.1444664)])
# OrderedDict([('sparse_categorical_accuracy', 0.733756), ('loss', 0.980741)])
# OrderedDict([('sparse_categorical_accuracy', 0.735959), ('loss', 0.8981289)])
# OrderedDict([('sparse_categorical_accuracy', 0.737352), ('loss', 0.8524383)])
# ##############################
# Monte Carlo Trial #  9
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# [<PrefetchDataset shapes: OrderedDict([(x, (None, 2)), (y, (None, 1))]), types: OrderedDict([(x, tf.float64), (y, tf.int32)])>]
# OrderedDict([('sparse_categorical_accuracy', 0.557031), ('loss', 1.5394233)])
# OrderedDict([('sparse_categorical_accuracy', 0.72518), ('loss', 1.1363981)])
# OrderedDict([('sparse_categorical_accuracy', 0.733198), ('loss', 0.9829664)])
# OrderedDict([('sparse_categorical_accuracy', 0.735495), ('loss', 0.9037296)])
# OrderedDict([('sparse_categorical_accuracy', 0.737363), ('loss', 0.8589891)])
# ##############################
# Monte Carlo Trial #  10
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# [<PrefetchDataset shapes: OrderedDict([(x, (None, 2)), (y, (None, 1))]), types: OrderedDict([(x, tf.float64), (y, tf.int32)])>]
# OrderedDict([('sparse_categorical_accuracy', 0.523055), ('loss', 1.6020586)])
# OrderedDict([('sparse_categorical_accuracy', 0.709876), ('loss', 1.1655389)])
# OrderedDict([('sparse_categorical_accuracy', 0.73369), ('loss', 0.9935051)])
# OrderedDict([('sparse_categorical_accuracy', 0.736077), ('loss', 0.9091267)])
# OrderedDict([('sparse_categorical_accuracy', 0.737331), ('loss', 0.8603725)])
# ##############################
# 4QAM at Eb/N0= 5 dB
# FedRec trained collaboratively by  5 users
# non-iid  Rayleigh fading
# BER=  0.06614315062761306
# 10
# WARNING:tensorflow:Please add `keras.layers.InputLayer` instead of `keras.Input` to Sequential model. `keras.Input` is intended to be used by Functional model.
# WARNING:tensorflow:Please add `keras.layers.InputLayer` instead of `keras.Input` to Sequential model. `keras.Input` is intended to be used by Functional model.
# WARNING:tensorflow:Please add `keras.layers.InputLayer` instead of `keras.Input` to Sequential model. `keras.Input` is intended to be used by Functional model.
# WARNING:tensorflow:Please add `keras.layers.InputLayer` instead of `keras.Input` to Sequential model. `keras.Input` is intended to be used by Functional model.
# WARNING:tensorflow:Please add `keras.layers.InputLayer` instead of `keras.Input` to Sequential model. `keras.Input` is intended to be used by Functional model.
# WARNING:tensorflow:Please add `keras.layers.InputLayer` instead of `keras.Input` to Sequential model. `keras.Input` is intended to be used by Functional model.
# WARNING:tensorflow:Please add `keras.layers.InputLayer` instead of `keras.Input` to Sequential model. `keras.Input` is intended to be used by Functional model.
# WARNING:tensorflow:Please add `keras.layers.InputLayer` instead of `keras.Input` to Sequential model. `keras.Input` is intended to be used by Functional model.
# WARNING:tensorflow:Please add `keras.layers.InputLayer` instead of `keras.Input` to Sequential model. `keras.Input` is intended to be used by Functional model.
# WARNING:tensorflow:Please add `keras.layers.InputLayer` instead of `keras.Input` to Sequential model. `keras.Input` is intended to be used by Functional model.
# WARNING:tensorflow:Please add `keras.layers.InputLayer` instead of `keras.Input` to Sequential model. `keras.Input` is intended to be used by Functional model.
# WARNING:tensorflow:Please add `keras.layers.InputLayer` instead of `keras.Input` to Sequential model. `keras.Input` is intended to be used by Functional model.
# <tensorflow_federated.python.core.impl.computation.computation_impl.ComputationImpl object at 0x7fb505837710>
# ##############################
# Monte Carlo Trial #  1
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# [<PrefetchDataset shapes: OrderedDict([(x, (None, 2)), (y, (None, 1))]), types: OrderedDict([(x, tf.float64), (y, tf.int32)])>]
# OrderedDict([('sparse_categorical_accuracy', 0.40693), ('loss', 2.011552)])
# OrderedDict([('sparse_categorical_accuracy', 0.595647), ('loss', 1.4985512)])
# OrderedDict([('sparse_categorical_accuracy', 0.683856), ('loss', 1.2719908)])
# OrderedDict([('sparse_categorical_accuracy', 0.724883), ('loss', 1.1341933)])
# OrderedDict([('sparse_categorical_accuracy', 0.729429), ('loss', 1.0448494)])
# ##############################
# Monte Carlo Trial #  2
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# [<PrefetchDataset shapes: OrderedDict([(x, (None, 2)), (y, (None, 1))]), types: OrderedDict([(x, tf.float64), (y, tf.int32)])>]
# OrderedDict([('sparse_categorical_accuracy', 0.262482), ('loss', 2.165516)])
# OrderedDict([('sparse_categorical_accuracy', 0.498388), ('loss', 1.580993)])
# OrderedDict([('sparse_categorical_accuracy', 0.706928), ('loss', 1.3109818)])
# OrderedDict([('sparse_categorical_accuracy', 0.730178), ('loss', 1.1551461)])
# OrderedDict([('sparse_categorical_accuracy', 0.731442), ('loss', 1.0559155)])
# ##############################
# Monte Carlo Trial #  3
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# [<PrefetchDataset shapes: OrderedDict([(x, (None, 2)), (y, (None, 1))]), types: OrderedDict([(x, tf.float64), (y, tf.int32)])>]
# OrderedDict([('sparse_categorical_accuracy', 0.299051), ('loss', 2.1788795)])
# OrderedDict([('sparse_categorical_accuracy', 0.645201), ('loss', 1.567084)])
# OrderedDict([('sparse_categorical_accuracy', 0.718779), ('loss', 1.2944635)])
# OrderedDict([('sparse_categorical_accuracy', 0.72066), ('loss', 1.159061)])
# OrderedDict([('sparse_categorical_accuracy', 0.721327), ('loss', 1.0653431)])
# ##############################
# Monte Carlo Trial #  4
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# [<PrefetchDataset shapes: OrderedDict([(x, (None, 2)), (y, (None, 1))]), types: OrderedDict([(x, tf.float64), (y, tf.int32)])>]
# OrderedDict([('sparse_categorical_accuracy', 0.380597), ('loss', 1.9917122)])
# OrderedDict([('sparse_categorical_accuracy', 0.625336), ('loss', 1.4707845)])
# OrderedDict([('sparse_categorical_accuracy', 0.716719), ('loss', 1.2418132)])
# OrderedDict([('sparse_categorical_accuracy', 0.725227), ('loss', 1.1090764)])
# OrderedDict([('sparse_categorical_accuracy', 0.727413), ('loss', 1.024399)])
# ##############################
# Monte Carlo Trial #  5
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# [<PrefetchDataset shapes: OrderedDict([(x, (None, 2)), (y, (None, 1))]), types: OrderedDict([(x, tf.float64), (y, tf.int32)])>]
# OrderedDict([('sparse_categorical_accuracy', 0.368821), ('loss', 2.0643072)])
# OrderedDict([('sparse_categorical_accuracy', 0.608102), ('loss', 1.5036625)])
# OrderedDict([('sparse_categorical_accuracy', 0.714523), ('loss', 1.2564126)])
# OrderedDict([('sparse_categorical_accuracy', 0.724252), ('loss', 1.1228354)])
# OrderedDict([('sparse_categorical_accuracy', 0.727278), ('loss', 1.0385473)])
# ##############################
# Monte Carlo Trial #  6
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# [<PrefetchDataset shapes: OrderedDict([(x, (None, 2)), (y, (None, 1))]), types: OrderedDict([(x, tf.float64), (y, tf.int32)])>]
# OrderedDict([('sparse_categorical_accuracy', 0.464462), ('loss', 1.8836036)])
# OrderedDict([('sparse_categorical_accuracy', 0.627434), ('loss', 1.3975246)])
# OrderedDict([('sparse_categorical_accuracy', 0.704669), ('loss', 1.1900603)])
# OrderedDict([('sparse_categorical_accuracy', 0.726435), ('loss', 1.0756012)])
# OrderedDict([('sparse_categorical_accuracy', 0.730807), ('loss', 0.999601)])
# ##############################
# Monte Carlo Trial #  7
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# [<PrefetchDataset shapes: OrderedDict([(x, (None, 2)), (y, (None, 1))]), types: OrderedDict([(x, tf.float64), (y, tf.int32)])>]
# OrderedDict([('sparse_categorical_accuracy', 0.37456), ('loss', 1.8883268)])
# OrderedDict([('sparse_categorical_accuracy', 0.609404), ('loss', 1.4270983)])
# OrderedDict([('sparse_categorical_accuracy', 0.71702), ('loss', 1.2116491)])
# OrderedDict([('sparse_categorical_accuracy', 0.727941), ('loss', 1.0929095)])
# OrderedDict([('sparse_categorical_accuracy', 0.730064), ('loss', 1.0141582)])
# ##############################
# Monte Carlo Trial #  8
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# [<PrefetchDataset shapes: OrderedDict([(x, (None, 2)), (y, (None, 1))]), types: OrderedDict([(x, tf.float64), (y, tf.int32)])>]
# OrderedDict([('sparse_categorical_accuracy', 0.428447), ('loss', 1.7606483)])
# OrderedDict([('sparse_categorical_accuracy', 0.709523), ('loss', 1.3789709)])
# OrderedDict([('sparse_categorical_accuracy', 0.711612), ('loss', 1.195552)])
# OrderedDict([('sparse_categorical_accuracy', 0.708534), ('loss', 1.0945092)])
# OrderedDict([('sparse_categorical_accuracy', 0.709616), ('loss', 1.0246148)])
# ##############################
# Monte Carlo Trial #  9
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# [<PrefetchDataset shapes: OrderedDict([(x, (None, 2)), (y, (None, 1))]), types: OrderedDict([(x, tf.float64), (y, tf.int32)])>]
# OrderedDict([('sparse_categorical_accuracy', 0.347859), ('loss', 1.9427131)])
# OrderedDict([('sparse_categorical_accuracy', 0.596078), ('loss', 1.4521753)])
# OrderedDict([('sparse_categorical_accuracy', 0.702955), ('loss', 1.2352854)])
# OrderedDict([('sparse_categorical_accuracy', 0.726369), ('loss', 1.1081235)])
# OrderedDict([('sparse_categorical_accuracy', 0.730531), ('loss', 1.0231192)])
# ##############################
# Monte Carlo Trial #  10
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# [<PrefetchDataset shapes: OrderedDict([(x, (None, 2)), (y, (None, 1))]), types: OrderedDict([(x, tf.float64), (y, tf.int32)])>]
# OrderedDict([('sparse_categorical_accuracy', 0.34857), ('loss', 2.0245202)])
# OrderedDict([('sparse_categorical_accuracy', 0.569291), ('loss', 1.515441)])
# OrderedDict([('sparse_categorical_accuracy', 0.709863), ('loss', 1.2738044)])
# OrderedDict([('sparse_categorical_accuracy', 0.716093), ('loss', 1.1369348)])
# OrderedDict([('sparse_categorical_accuracy', 0.717868), ('loss', 1.0470914)])
# ##############################
# 4QAM at Eb/N0= 5 dB
# FedRec trained collaboratively by  10 users
# non-iid  Rayleigh fading
# BER=  0.06860562711954116
# 100
# WARNING:tensorflow:Please add `keras.layers.InputLayer` instead of `keras.Input` to Sequential model. `keras.Input` is intended to be used by Functional model.
# WARNING:tensorflow:Please add `keras.layers.InputLayer` instead of `keras.Input` to Sequential model. `keras.Input` is intended to be used by Functional model.
# WARNING:tensorflow:Please add `keras.layers.InputLayer` instead of `keras.Input` to Sequential model. `keras.Input` is intended to be used by Functional model.
# WARNING:tensorflow:Please add `keras.layers.InputLayer` instead of `keras.Input` to Sequential model. `keras.Input` is intended to be used by Functional model.
# WARNING:tensorflow:Please add `keras.layers.InputLayer` instead of `keras.Input` to Sequential model. `keras.Input` is intended to be used by Functional model.
# WARNING:tensorflow:Please add `keras.layers.InputLayer` instead of `keras.Input` to Sequential model. `keras.Input` is intended to be used by Functional model.
# WARNING:tensorflow:Please add `keras.layers.InputLayer` instead of `keras.Input` to Sequential model. `keras.Input` is intended to be used by Functional model.
# WARNING:tensorflow:Please add `keras.layers.InputLayer` instead of `keras.Input` to Sequential model. `keras.Input` is intended to be used by Functional model.
# WARNING:tensorflow:Please add `keras.layers.InputLayer` instead of `keras.Input` to Sequential model. `keras.Input` is intended to be used by Functional model.
# WARNING:tensorflow:Please add `keras.layers.InputLayer` instead of `keras.Input` to Sequential model. `keras.Input` is intended to be used by Functional model.
# WARNING:tensorflow:Please add `keras.layers.InputLayer` instead of `keras.Input` to Sequential model. `keras.Input` is intended to be used by Functional model.
# WARNING:tensorflow:Please add `keras.layers.InputLayer` instead of `keras.Input` to Sequential model. `keras.Input` is intended to be used by Functional model.
# <tensorflow_federated.python.core.impl.computation.computation_impl.ComputationImpl object at 0x7fb4ff902e10>
# ##############################
# Monte Carlo Trial #  1
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# [<PrefetchDataset shapes: OrderedDict([(x, (None, 2)), (y, (None, 1))]), types: OrderedDict([(x, tf.float64), (y, tf.int32)])>]
# OrderedDict([('sparse_categorical_accuracy', 0.100927), ('loss', 3.3973124)])
# OrderedDict([('sparse_categorical_accuracy', 0.103545), ('loss', 3.147549)])
# OrderedDict([('sparse_categorical_accuracy', 0.181704), ('loss', 2.93952)])
# OrderedDict([('sparse_categorical_accuracy', 0.188351), ('loss', 2.7576356)])
# OrderedDict([('sparse_categorical_accuracy', 0.187847), ('loss', 2.5935657)])
# ##############################
# Monte Carlo Trial #  2
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# ...
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# [<PrefetchDataset shapes: OrderedDict([(x, (None, 2)), (y, (None, 1))]), types: OrderedDict([(x, tf.float64), (y, tf.int32)])>]
# OrderedDict([('sparse_categorical_accuracy', 0.064665), ('loss', 3.2969434)])
# OrderedDict([('sparse_categorical_accuracy', 0.10888), ('loss', 3.0392182)])
# OrderedDict([('sparse_categorical_accuracy', 0.151497), ('loss', 2.8172765)])
# OrderedDict([('sparse_categorical_accuracy', 0.164129), ('loss', 2.6272333)])
# OrderedDict([('sparse_categorical_accuracy', 0.165456), ('loss', 2.465175)])
# ##############################
# Monte Carlo Trial #  4
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# [<PrefetchDataset shapes: OrderedDict([(x, (None, 2)), (y, (None, 1))]), types: OrderedDict([(x, tf.float64), (y, tf.int32)])>]
# OrderedDict([('sparse_categorical_accuracy', 0.095658), ('loss', 3.5575192)])
# OrderedDict([('sparse_categorical_accuracy', 0.127725), ('loss', 3.302483)])
# OrderedDict([('sparse_categorical_accuracy', 0.206263), ('loss', 3.073299)])
# OrderedDict([('sparse_categorical_accuracy', 0.224106), ('loss', 2.8670025)])
# OrderedDict([('sparse_categorical_accuracy', 0.247752), ('loss', 2.6842563)])
# ##############################
# Monte Carlo Trial #  5
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# <TensorSliceDataset shapes: ((2,), ()), types: (tf.float64, tf.int32)>
# [<PrefetchDataset shapes: OrderedDict([(x, (None, 2)), (y, (None, 1))]), types: OrderedDict([(x, tf.float64), (y, tf.int32)])>]
